# %% [markdown]
# ## Try knocking out some frequency bands
# ## maybe Merged456 will work better?

# %%
import scipy.io as sio
# from URL_download_2 import gdown
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def download_data_from_GDRIVE():
    # imports the custom GDrive downloader library:
    # provide file ID:
    file_id = '1YPr_K8xSuKghONozyjnVThe47EsiDEZj'

    # instantiate class (create a class instance):
    G = gdown()

    # Download data from Google Drive as necessary:
    G.download_file(file_id)

def group_frequency_bands(X):
    X_ = np.zeros([X.shape[0],X.shape[1],X.shape[2], 2])
#     X_[:,:,:,0] = np.mean(X[:,:,:,3:6],axis=3)
#     X_[:,:,:,1] = np.mean(X[:,:,:,7:11],axis=3)
#     X_[:,:,:,2] = np.mean(X[:,:,:,12:29],axis=3)
    
#     processing frequencies: 0 16
#     processing frequencies: 16 32
#     processing frequencies: 32 49
#     processing frequencies: 49 65
#     X_[:,:,:,0] = np.mean(X[:,:,:,0:16],axis=3)
#     X_[:,:,:,1] = np.mean(X[:,:,:,16:32],axis=3)
    X_[:,:,:,0] = np.mean(X[:,:,:,32:49],axis=3)
    X_[:,:,:,1] = np.mean(X[:,:,:,49:65],axis=3)
    
    X_.shape
    # subplot(1,3,1)
    # imagesc(squeeze(mean(X(1,:,:,4:7), 4)))
    # title('Theta')

    # subplot(1,3,2)
    # imagesc(squeeze(mean(X(1,:,:,8:12), 4)))
    # title('Alpha')

    # subplot(1,3,3)
    # imagesc(squeeze(mean(X(1,:,:,13:30), 4)))
    # title('Beta')
    return X_

def im_resize(X_, height, width):
    
    if width>0 and height>0:
        X__ = np.zeros([X_.shape[0], height, width, X_.shape[3]])
        for i in range(X_.shape[0]):
                for j in range(X_.shape[3]):
                    im = Image.fromarray(X_[i,:,:,j])
                    X__[i,:,:,j] = im.resize((height, width), Image.ANTIALIAS)
        print (X__.shape)

        plt.subplot(121)
        plt.imshow(np.array(X_[200,:,:,1]))
        plt.subplot(122)
        plt.imshow(np.array(X__[200,:,:,1]))
    else:
        print('IMAGES NOT RESIZED')
    return X__

def downsample_frequency_domain(n_bins):
    print('Downsampling the frequency domain from', X.shape[3],'to', n_bins)
    xx = np.zeros([X.shape[0],X.shape[1],X.shape[2],n_bins])
    print(xx.shape)
    a = np.round(np.linspace(0,X.shape[3],n_bins+1))
    a = a.astype('uint8')
    print(a)
    for i in range(n_bins):
        xx[:,:,:,i] = np.mean(X[:,:,:,a[i]:a[i+1]], axis=3)   
        print('processing frequencies:', a[i], a[i+1])
    print(xx.shape)
    return xx

def parse_array(in_array):
    new_array = []
    for i in range(len(in_array)):
        if str(in_array[i]).find("left")>0:
            new_array.append("left")
        if str(in_array[i]).find("right")>0:
            new_array.append("right")
        if (str(in_array[i]).find("left")<0 and 
            str(in_array[i]).find("right")<0):
            print(i)
            new_array.append("unknown")
    return new_array

def find_right(Q, label):
    idx = []
    for i in range(len(Q)):
        if Q[i] == label:
            idx.append(i)
    return(idx)

# %%
file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat' #0.77
# file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=1, win=2, TOPO, .mat' #2# #0.77
# file = 'Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat' #1# #0.76 #0.79
# file = 'EEG_ICA(-123_ICs)+proc_AUD_101_192_Merged456.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat'



# file = 'Merged123_1_64_ICA(-eyes)AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=1, win=1, TOPO, .mat'
# file = 'Merged123_75_134_ICA(-eyes)AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=1, win=2, TOPO, .mat'
# file = 'Merged123-143-202_ICA(-Eyes)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=1, win=2, TOPO, .mat' #0.56

SHUFFLE = False
BATCH_SIZE = 20
TEST_TRAIN = 0.2
DS_FREQ = 1 #(0 1 2)
n_bins = 8
RESIZE = 1
width = 15
height = 15
SENSITIVITY = 0
knockouts = [0, 1, 2]

path = '/home/amplifier/home/DATASETS/' + file
mat_contents = sio.loadmat(path)
X = mat_contents['X']
Y = mat_contents['Z']
# Z = mat_contents['Z']
Q = parse_array(mat_contents['Q'])

# %%
X.shape
# Out:
# (450, 67, 67, 65)

# %%
SHUFFLE = False
BATCH_SIZE = 20
TEST_TRAIN = 0.2
DS_FREQ = 1 #(0 1 2)
n_bins = 8
RESIZE = 1
width = 15
height = 15
SENSITIVITY = 0
knockouts = [0, 1, 2]

X = list()
Y = list()
Q = list()
# 'EEG_ICA(-123_ICs)+proc_AUD_101_192_Merged456.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat'
# 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat',
# 'EEG_ICA(-123_ICs)+proc_AUD_101_192_Merged456.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat'
files = list(['Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat'])

for file_name in files:
    path = '/home/amplifier/home/DATASETS/' + file_name
    print (path)
    mat_contents = sio.loadmat(path)
    X.append(mat_contents['X'])
    Y.append(mat_contents['Z'])
    Q.append(parse_array(mat_contents['Q']))
    
print('Concatenating datasets...')
X = np.concatenate(X, axis=0)
Y = np.concatenate(Y, axis=0)
Q = np.concatenate(Q,axis=0)
# Out:
# /home/amplifier/home/DATASETS/Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TOPO, .mat
# Concatenating datasets...

# %%
if DS_FREQ==1:
    X = downsample_frequency_domain(n_bins)
    print('Downsampled Frequency Domain shape', X.shape)
if DS_FREQ==2:
    X = group_frequency_bands(X)
    print('Grouped Frequency Bands shape', X.shape)
if RESIZE==1:
    X = im_resize(X, height, width)
    print('Resized shape', X.shape)

if SENSITIVITY==1:
    X = np.delete(X, knockouts, axis=3)
    print('sens', X.shape)
if X.shape[1]<X.shape[2]:
    X = np.transpose(X,[0,2,1])

if Y.shape[1] > Y.shape[0]:
    Y = Y.T
    
# verify that the model REALLY finds a mapping between the input and the labels. If we get
# our accuracy by chance, then we should get the same accuracy on a permuted dataset:
# Y = np.random.permutation(Y)

print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
x_train, x_test, y_train, y_test, q_train, q_test = train_test_split(X, Y, Q, test_size=TEST_TRAIN, shuffle=SHUFFLE)
print('Original data type:', x_train.dtype)


# convert to float64 for numerical stability:
x_train = x_train.astype('float64')
y_train = y_train.astype('float64')
x_test = x_test.astype('float64')
y_test = y_test.astype('float64')
print('y_test.shape before', y_test.shape)


# # normalize to unit variance and zero mean:
# for i in range(x_train.shape[0]):
#     for j in range(x_train.shape[3]):
#         x_train[i,:,:,j] = preprocessing.scale(x_train[i,:,:,j], axis=1)
#         x_train[i,:,:,j] = preprocessing.minmax_scale(x_train[i,:,:,j], axis=1)
# #     y_train[i,:] = preprocessing.scale(y_train[i,:], axis=0)
# #     y_train[i,:] = preprocessing.minmax_scale(y_train[i,:], axis=0)

# for i in range(x_test.shape[0]):
#     for j in range(x_train.shape[3]):
#         x_test[i,:,:,j] = preprocessing.scale(x_test[i,:,:,j], axis=1)
#         x_test[i,:,:,j] = preprocessing.minmax_scale(x_test[i,:,:,j], axis=1)
# #     y_test[i,:] = preprocessing.scale(y_test[i,:], axis=0)
# #     y_test[i,:] = preprocessing.minmax_scale(y_test[i,:], axis=0)
    

# one hot encode the labels:
onehot_encoder = preprocessing.OneHotEncoder(sparse=False)
y_train = onehot_encoder.fit_transform(y_train)
y_test = onehot_encoder.fit_transform(y_test)
print('y_test.shape after', y_test.shape)

# convert to float16 to save space:
x_train = x_train.astype('float16')
y_train = y_train.astype('float16')
x_test = x_test.astype('float16')
y_test = y_test.astype('float16')
print('Normalized data type:', x_train.dtype)

leng = X.shape[1] # if you work in the FD, this is the height of the sample time-frequency image, othewise EEG channels
chan = X.shape[2] # if you work in the FD, this is the width of the sample time-frequency image, othewise time samples of EEG signal

if len(X.shape)==3:
    streams = 1 # this is EEG channels if you work with frequency domain, in the TD streams = 1
if len(X.shape)==4:
    streams = X.shape[3] # this is EEG channels if you work with frequency domain, in the TD streams = 1


print('Prepped test input shape', x_test.shape, "Noralized MEAN:", np.mean(x_test), "min", np.min(x_test),"max", np.max(x_test))
print('Prepped train input shape', x_train.shape, "Normalized MEAN:", np.mean(x_train), "min", np.min(x_train),"max", np.max(x_train))

print('Prepped test labels shape', y_test.shape, "Normalized MEAN:", np.mean(y_test), "min", np.min(y_test),"max", np.max(y_test))
print('Prepped train labels shape', y_train.shape, "Normalized MEAN:", np.mean(y_train), "min", np.min(y_train),"max", np.max(y_train))

# print('Window length', winsize)
# print('Step size:', stepsize)
# print('Trial length:', trial_len)

print('EEG in dataset:', X.shape)
print('Labels in dataset:', Y.shape)
print('Length of textual labels:', len(Q))
# Out:
# Downsampling the frequency domain from 65 to 8
# (450, 67, 67, 8)
# [ 0  8 16 24 32 41 49 57 65]
# processing frequencies: 0 8
# processing frequencies: 8 16
# processing frequencies: 16 24
# processing frequencies: 24 32
# processing frequencies: 32 41
# processing frequencies: 41 49
# processing frequencies: 49 57
# processing frequencies: 57 65
# (450, 67, 67, 8)
# Downsampled Frequency Domain shape (450, 67, 67, 8)
# (450, 15, 15, 8)
# Resized shape (450, 15, 15, 8)
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Original data type: float64
# y_test.shape before (90, 1)
# y_test.shape after (90, 2)
# Normalized data type: float16
# Prepped test input shape (90, 15, 15, 8) Noralized MEAN: 0.09375 min -0.02908 max 1.109
# Prepped train input shape (360, 15, 15, 8) Normalized MEAN: 0.0941 min -0.0571 max 2.4
# Prepped test labels shape (90, 2) Normalized MEAN: 0.5 min 0.0 max 1.0
# Prepped train labels shape (360, 2) Normalized MEAN: 0.5 min 0.0 max 1.0
# EEG in dataset: (450, 15, 15, 8)
# Labels in dataset: (450, 1)
# Length of textual labels: 450

# %%
print(X.shape)

f, axs = plt.subplots(1,4,figsize=(18,18))

axs[0].imshow(X[100,:,:,2])
axs[0].set_title('1-5 Hz')
axs[1].imshow(X[300,:,:,4])
axs[1].set_title('5-10 Hz')
axs[2].imshow(X[300,:,:,6])
axs[2].set_title('15-20 Hz')
axs[3].imshow(X[300,:,:,7])
axs[3].set_title('25-30 Hz')
# Out:
# (450, 15, 15, 8)
# Text(0.5,1,'25-30 Hz')

# %%
dilation_rate = 1

# make sure you don't hog all the video memory
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
from keras import backend as K
K.set_session(sess)
###################################

def activation():
    return ELU(alpha=1.0) # Activation('relu') #

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout, ELU
from keras.models import Model
from keras.callbacks import TensorBoard, EarlyStopping
from keras.optimizers import Adam

sh = x_train.shape


input_img = Input(shape=(sh[1], sh[2], sh[3]))  # adapt this if using `channels_first` image data format

x = Conv2D(30, (3, 3), activation='relu', padding='same', dilation_rate=dilation_rate)(input_img)
x = BatchNormalization()(x)
x = Conv2D(30, (3, 3), activation='relu', padding='same', dilation_rate=dilation_rate)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(60, (3, 3), activation='relu', padding='same', dilation_rate=dilation_rate)(x)
x = BatchNormalization()(x)
x = Conv2D(60, (3, 3), activation='relu', padding='same', dilation_rate=dilation_rate)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(120, (2, 2), activation='relu', padding='same', dilation_rate=dilation_rate)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(100, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(10, activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(2, activation='softmax')(x)

model = Model(input_img, x)
optimizer=Adam(0.00006)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 15, 15, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 15, 15, 30)        2190
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 15, 15, 30)        120
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 30)        8130
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 15, 15, 30)        120
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 30)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 60)          16260
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 60)          240
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 60)          32460
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 60)          240
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 60)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 120)         28920
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 4, 120)         480
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 120)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 480)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               48100
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 100)               400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10)                40
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 138,732
# Trainable params: 137,912
# Non-trainable params: 820
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
early_stopping = EarlyStopping(monitor='val_loss', patience=100, mode='min')
checkpointer = ModelCheckpoint(filepath='/home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5',
                               verbose=1,
                               monitor='val_acc',
                               save_best_only=True)

train_history = model.fit(x_train, y_train,
                epochs=300,
                batch_size=BATCH_SIZE,
                verbose=2,
                shuffle=True,
                validation_data=(x_test, y_test),
                callbacks=[checkpointer, early_stopping])
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/300
#  - 3s - loss: 1.0864 - acc: 0.4972 - val_loss: 0.7266 - val_acc: 0.5444
#
# Epoch 00001: val_acc improved from -inf to 0.54444, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 2/300
#  - 0s - loss: 1.0129 - acc: 0.5194 - val_loss: 0.7074 - val_acc: 0.5556
#
# Epoch 00002: val_acc improved from 0.54444 to 0.55556, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 3/300
#  - 0s - loss: 0.9691 - acc: 0.5417 - val_loss: 0.6973 - val_acc: 0.5556
#
# Epoch 00003: val_acc did not improve from 0.55556
# Epoch 4/300
#  - 0s - loss: 0.9168 - acc: 0.5556 - val_loss: 0.7115 - val_acc: 0.5556
#
# Epoch 00004: val_acc did not improve from 0.55556
# Epoch 5/300
#  - 0s - loss: 0.8488 - acc: 0.5722 - val_loss: 0.6894 - val_acc: 0.5667
#
# Epoch 00005: val_acc improved from 0.55556 to 0.56667, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 6/300
#  - 0s - loss: 0.9147 - acc: 0.5444 - val_loss: 0.6851 - val_acc: 0.6111
#
# Epoch 00006: val_acc improved from 0.56667 to 0.61111, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 7/300
#  - 0s - loss: 0.9720 - acc: 0.5528 - val_loss: 0.6893 - val_acc: 0.6000
#
# Epoch 00007: val_acc did not improve from 0.61111
# Epoch 8/300
#  - 0s - loss: 0.9062 - acc: 0.5500 - val_loss: 0.6963 - val_acc: 0.6222
#
# Epoch 00008: val_acc improved from 0.61111 to 0.62222, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 9/300
#  - 0s - loss: 0.9622 - acc: 0.5417 - val_loss: 0.7041 - val_acc: 0.6111
#
# Epoch 00009: val_acc did not improve from 0.62222
# Epoch 10/300
#  - 0s - loss: 0.8646 - acc: 0.5639 - val_loss: 0.7032 - val_acc: 0.6222
#
# Epoch 00010: val_acc did not improve from 0.62222
# Epoch 11/300
#  - 0s - loss: 0.9509 - acc: 0.5583 - val_loss: 0.6929 - val_acc: 0.6444
#
# Epoch 00011: val_acc improved from 0.62222 to 0.64444, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 12/300
#  - 0s - loss: 0.8863 - acc: 0.5806 - val_loss: 0.6887 - val_acc: 0.6222
#
# Epoch 00012: val_acc did not improve from 0.64444
# Epoch 13/300
#  - 0s - loss: 0.8645 - acc: 0.5639 - val_loss: 0.6597 - val_acc: 0.6778
#
# Epoch 00013: val_acc improved from 0.64444 to 0.67778, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 14/300
#  - 0s - loss: 0.8078 - acc: 0.6194 - val_loss: 0.6397 - val_acc: 0.6889
#
# Epoch 00014: val_acc improved from 0.67778 to 0.68889, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 15/300
#  - 0s - loss: 0.7721 - acc: 0.6056 - val_loss: 0.6277 - val_acc: 0.7000
#
# Epoch 00015: val_acc improved from 0.68889 to 0.70000, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 16/300
#  - 0s - loss: 0.7979 - acc: 0.5861 - val_loss: 0.6157 - val_acc: 0.6889
#
# Epoch 00016: val_acc did not improve from 0.70000
# Epoch 17/300
#  - 0s - loss: 0.7888 - acc: 0.6139 - val_loss: 0.6298 - val_acc: 0.6778
#
# Epoch 00017: val_acc did not improve from 0.70000
# Epoch 18/300
#  - 0s - loss: 0.7759 - acc: 0.6167 - val_loss: 0.6387 - val_acc: 0.6556
#
# Epoch 00018: val_acc did not improve from 0.70000
# Epoch 19/300
#  - 0s - loss: 0.7818 - acc: 0.6278 - val_loss: 0.6298 - val_acc: 0.6667
#
# Epoch 00019: val_acc did not improve from 0.70000
# Epoch 20/300
#  - 0s - loss: 0.7591 - acc: 0.6222 - val_loss: 0.6154 - val_acc: 0.6667
#
# Epoch 00020: val_acc did not improve from 0.70000
# Epoch 21/300
#  - 0s - loss: 0.6959 - acc: 0.6306 - val_loss: 0.6071 - val_acc: 0.6778
#
# Epoch 00021: val_acc did not improve from 0.70000
# Epoch 22/300
#  - 0s - loss: 0.8180 - acc: 0.6222 - val_loss: 0.6030 - val_acc: 0.6889
#
# Epoch 00022: val_acc did not improve from 0.70000
# Epoch 23/300
#  - 0s - loss: 0.7872 - acc: 0.5889 - val_loss: 0.6101 - val_acc: 0.7111
#
# Epoch 00023: val_acc improved from 0.70000 to 0.71111, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 24/300
#  - 0s - loss: 0.7769 - acc: 0.6139 - val_loss: 0.6078 - val_acc: 0.7111
#
# Epoch 00024: val_acc did not improve from 0.71111
# Epoch 25/300
#  - 0s - loss: 0.6757 - acc: 0.6722 - val_loss: 0.6019 - val_acc: 0.7000
#
# Epoch 00025: val_acc did not improve from 0.71111
# Epoch 26/300
#  - 0s - loss: 0.7215 - acc: 0.6389 - val_loss: 0.6007 - val_acc: 0.7000
#
# Epoch 00026: val_acc did not improve from 0.71111
# Epoch 27/300
#  - 0s - loss: 0.6725 - acc: 0.6611 - val_loss: 0.5920 - val_acc: 0.7000
#
# Epoch 00027: val_acc did not improve from 0.71111
# Epoch 28/300
#  - 0s - loss: 0.6688 - acc: 0.6333 - val_loss: 0.5945 - val_acc: 0.7111
#
# Epoch 00028: val_acc did not improve from 0.71111
# Epoch 29/300
#  - 0s - loss: 0.7754 - acc: 0.5972 - val_loss: 0.5894 - val_acc: 0.6889
#
# Epoch 00029: val_acc did not improve from 0.71111
# Epoch 30/300
#  - 0s - loss: 0.7163 - acc: 0.6556 - val_loss: 0.6097 - val_acc: 0.7000
#
# Epoch 00030: val_acc did not improve from 0.71111
# Epoch 31/300
#  - 0s - loss: 0.7193 - acc: 0.6444 - val_loss: 0.6058 - val_acc: 0.7111
#
# Epoch 00031: val_acc did not improve from 0.71111
# Epoch 32/300
#  - 0s - loss: 0.6296 - acc: 0.7000 - val_loss: 0.6017 - val_acc: 0.6889
#
# Epoch 00032: val_acc did not improve from 0.71111
# Epoch 33/300
#  - 0s - loss: 0.6526 - acc: 0.6639 - val_loss: 0.5910 - val_acc: 0.7111
#
# Epoch 00033: val_acc did not improve from 0.71111
# Epoch 34/300
#  - 0s - loss: 0.7117 - acc: 0.6167 - val_loss: 0.5783 - val_acc: 0.7222
#
# Epoch 00034: val_acc improved from 0.71111 to 0.72222, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 35/300
#  - 0s - loss: 0.6975 - acc: 0.6444 - val_loss: 0.5684 - val_acc: 0.7333
#
# Epoch 00035: val_acc improved from 0.72222 to 0.73333, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 36/300
#  - 0s - loss: 0.6267 - acc: 0.7000 - val_loss: 0.5601 - val_acc: 0.7556
#
# Epoch 00036: val_acc improved from 0.73333 to 0.75556, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 37/300
#  - 0s - loss: 0.6680 - acc: 0.6667 - val_loss: 0.5550 - val_acc: 0.7444
#
# Epoch 00037: val_acc did not improve from 0.75556
# Epoch 38/300
#  - 0s - loss: 0.6262 - acc: 0.6917 - val_loss: 0.5538 - val_acc: 0.7333
#
# Epoch 00038: val_acc did not improve from 0.75556
# Epoch 39/300
#  - 0s - loss: 0.5534 - acc: 0.7250 - val_loss: 0.5509 - val_acc: 0.7778
#
# Epoch 00039: val_acc improved from 0.75556 to 0.77778, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 40/300
#  - 0s - loss: 0.6239 - acc: 0.6917 - val_loss: 0.5559 - val_acc: 0.7667
#
# Epoch 00040: val_acc did not improve from 0.77778
# Epoch 41/300
#  - 0s - loss: 0.5872 - acc: 0.7194 - val_loss: 0.5675 - val_acc: 0.7333
#
# Epoch 00041: val_acc did not improve from 0.77778
# Epoch 42/300
#  - 0s - loss: 0.5408 - acc: 0.7250 - val_loss: 0.5792 - val_acc: 0.7222
#
# Epoch 00042: val_acc did not improve from 0.77778
# Epoch 43/300
#  - 0s - loss: 0.6035 - acc: 0.6889 - val_loss: 0.5850 - val_acc: 0.7333
#
# Epoch 00043: val_acc did not improve from 0.77778
# Epoch 44/300
#  - 0s - loss: 0.5741 - acc: 0.7250 - val_loss: 0.5905 - val_acc: 0.7444
#
# Epoch 00044: val_acc did not improve from 0.77778
# Epoch 45/300
#  - 0s - loss: 0.5555 - acc: 0.7250 - val_loss: 0.5825 - val_acc: 0.7444
#
# Epoch 00045: val_acc did not improve from 0.77778
# Epoch 46/300
#  - 0s - loss: 0.5482 - acc: 0.7167 - val_loss: 0.5748 - val_acc: 0.7556
#
# Epoch 00046: val_acc did not improve from 0.77778
# Epoch 47/300
#  - 0s - loss: 0.5170 - acc: 0.7611 - val_loss: 0.5723 - val_acc: 0.7778
#
# Epoch 00047: val_acc improved from 0.77778 to 0.77778, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 48/300
#  - 0s - loss: 0.5450 - acc: 0.7361 - val_loss: 0.5681 - val_acc: 0.7778
#
# Epoch 00048: val_acc did not improve from 0.77778
# Epoch 49/300
#  - 0s - loss: 0.5794 - acc: 0.7083 - val_loss: 0.5623 - val_acc: 0.7556
#
# Epoch 00049: val_acc did not improve from 0.77778
# Epoch 50/300
#  - 0s - loss: 0.4929 - acc: 0.7444 - val_loss: 0.5627 - val_acc: 0.7667
#
# Epoch 00050: val_acc did not improve from 0.77778
# Epoch 51/300
#  - 0s - loss: 0.5205 - acc: 0.7444 - val_loss: 0.5632 - val_acc: 0.7889
#
# Epoch 00051: val_acc improved from 0.77778 to 0.78889, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 52/300
#  - 0s - loss: 0.5242 - acc: 0.7417 - val_loss: 0.5610 - val_acc: 0.7667
# Epoch 00052: val_acc did not improve from 0.78889
# Epoch 53/300
#  - 0s - loss: 0.5423 - acc: 0.7333 - val_loss: 0.5518 - val_acc: 0.7778
#
# Epoch 00053: val_acc did not improve from 0.78889
# Epoch 54/300
#  - 0s - loss: 0.5019 - acc: 0.7778 - val_loss: 0.5575 - val_acc: 0.7889
#
# Epoch 00054: val_acc did not improve from 0.78889
# Epoch 55/300
#  - 0s - loss: 0.5358 - acc: 0.7111 - val_loss: 0.5657 - val_acc: 0.7889
#
# Epoch 00055: val_acc did not improve from 0.78889
# Epoch 56/300
#  - 0s - loss: 0.4906 - acc: 0.7417 - val_loss: 0.5612 - val_acc: 0.8000
#
# Epoch 00056: val_acc improved from 0.78889 to 0.80000, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 57/300
#  - 0s - loss: 0.5632 - acc: 0.7472 - val_loss: 0.5568 - val_acc: 0.7889
#
# Epoch 00057: val_acc did not improve from 0.80000
# Epoch 58/300
#  - 0s - loss: 0.4719 - acc: 0.7667 - val_loss: 0.5539 - val_acc: 0.7889
#
# Epoch 00058: val_acc did not improve from 0.80000
# Epoch 59/300
#  - 0s - loss: 0.4876 - acc: 0.7889 - val_loss: 0.5487 - val_acc: 0.7889
#
# Epoch 00059: val_acc did not improve from 0.80000
# Epoch 60/300
#  - 0s - loss: 0.5151 - acc: 0.7500 - val_loss: 0.5348 - val_acc: 0.7667
#
# Epoch 00060: val_acc did not improve from 0.80000
# Epoch 61/300
#  - 0s - loss: 0.4960 - acc: 0.7333 - val_loss: 0.5389 - val_acc: 0.8000
#
# Epoch 00061: val_acc did not improve from 0.80000
# Epoch 62/300
#  - 0s - loss: 0.5207 - acc: 0.7500 - val_loss: 0.5350 - val_acc: 0.7667
#
# Epoch 00062: val_acc did not improve from 0.80000
# Epoch 63/300
#  - 0s - loss: 0.4321 - acc: 0.7917 - val_loss: 0.5329 - val_acc: 0.7556
#
# Epoch 00063: val_acc did not improve from 0.80000
# Epoch 64/300
#  - 0s - loss: 0.4754 - acc: 0.7722 - val_loss: 0.5192 - val_acc: 0.7778
#
# Epoch 00064: val_acc did not improve from 0.80000
# Epoch 65/300
#  - 0s - loss: 0.4577 - acc: 0.7917 - val_loss: 0.5134 - val_acc: 0.7889
#
# Epoch 00065: val_acc did not improve from 0.80000
# Epoch 66/300
#  - 0s - loss: 0.4425 - acc: 0.7806 - val_loss: 0.5195 - val_acc: 0.7444
#
# Epoch 00066: val_acc did not improve from 0.80000
# Epoch 67/300
#  - 0s - loss: 0.4706 - acc: 0.7694 - val_loss: 0.5264 - val_acc: 0.7444
#
# Epoch 00067: val_acc did not improve from 0.80000
# Epoch 68/300
#  - 0s - loss: 0.4608 - acc: 0.8000 - val_loss: 0.5165 - val_acc: 0.7778
#
# Epoch 00068: val_acc did not improve from 0.80000
# Epoch 69/300
#  - 0s - loss: 0.4828 - acc: 0.7667 - val_loss: 0.5144 - val_acc: 0.7778
#
# Epoch 00069: val_acc did not improve from 0.80000
# Epoch 70/300
#  - 0s - loss: 0.4360 - acc: 0.7917 - val_loss: 0.5129 - val_acc: 0.7889
#
# Epoch 00070: val_acc did not improve from 0.80000
# Epoch 71/300
#  - 0s - loss: 0.4477 - acc: 0.7750 - val_loss: 0.5108 - val_acc: 0.8000
#
# Epoch 00071: val_acc improved from 0.80000 to 0.80000, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 72/300
#  - 0s - loss: 0.4253 - acc: 0.7917 - val_loss: 0.5135 - val_acc: 0.7889
#
# Epoch 00072: val_acc did not improve from 0.80000
# Epoch 73/300
#  - 0s - loss: 0.4194 - acc: 0.8194 - val_loss: 0.5153 - val_acc: 0.7778
#
# Epoch 00073: val_acc did not improve from 0.80000
# Epoch 74/300
#  - 0s - loss: 0.4000 - acc: 0.8333 - val_loss: 0.5134 - val_acc: 0.7667
#
# Epoch 00074: val_acc did not improve from 0.80000
# Epoch 75/300
#  - 0s - loss: 0.4545 - acc: 0.7944 - val_loss: 0.5254 - val_acc: 0.7889
#
# Epoch 00075: val_acc did not improve from 0.80000
# Epoch 76/300
#  - 0s - loss: 0.4397 - acc: 0.8056 - val_loss: 0.5434 - val_acc: 0.7889
#
# Epoch 00076: val_acc did not improve from 0.80000
# Epoch 77/300
#  - 0s - loss: 0.4480 - acc: 0.7861 - val_loss: 0.5603 - val_acc: 0.7667
#
# Epoch 00077: val_acc did not improve from 0.80000
# Epoch 78/300
#  - 0s - loss: 0.4287 - acc: 0.7944 - val_loss: 0.5383 - val_acc: 0.7889
#
# Epoch 00078: val_acc did not improve from 0.80000
# Epoch 79/300
#  - 0s - loss: 0.4181 - acc: 0.8083 - val_loss: 0.5176 - val_acc: 0.8111
#
# Epoch 00079: val_acc improved from 0.80000 to 0.81111, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 80/300
#  - 0s - loss: 0.4234 - acc: 0.8083 - val_loss: 0.5352 - val_acc: 0.7778
#
# Epoch 00080: val_acc did not improve from 0.81111
# Epoch 81/300
#  - 0s - loss: 0.3978 - acc: 0.8111 - val_loss: 0.5486 - val_acc: 0.7667
#
# Epoch 00081: val_acc did not improve from 0.81111
# Epoch 82/300
#  - 0s - loss: 0.4357 - acc: 0.8111 - val_loss: 0.5308 - val_acc: 0.7778
#
# Epoch 00082: val_acc did not improve from 0.81111
# Epoch 83/300
#  - 0s - loss: 0.4011 - acc: 0.8111 - val_loss: 0.5221 - val_acc: 0.7889
#
# Epoch 00083: val_acc did not improve from 0.81111
# Epoch 84/300
#  - 0s - loss: 0.3780 - acc: 0.8583 - val_loss: 0.5276 - val_acc: 0.7889
#
# Epoch 00084: val_acc did not improve from 0.81111
# Epoch 85/300
#  - 0s - loss: 0.3606 - acc: 0.8639 - val_loss: 0.5218 - val_acc: 0.8111
#
# Epoch 00085: val_acc did not improve from 0.81111
# Epoch 86/300
#  - 0s - loss: 0.3511 - acc: 0.8556 - val_loss: 0.5060 - val_acc: 0.8000
#
# Epoch 00086: val_acc did not improve from 0.81111
# Epoch 87/300
#  - 0s - loss: 0.3828 - acc: 0.8389 - val_loss: 0.5073 - val_acc: 0.8111
#
# Epoch 00087: val_acc did not improve from 0.81111
# Epoch 88/300
#  - 0s - loss: 0.3475 - acc: 0.8500 - val_loss: 0.5063 - val_acc: 0.8000
#
# Epoch 00088: val_acc did not improve from 0.81111
# Epoch 89/300
#  - 0s - loss: 0.3864 - acc: 0.8389 - val_loss: 0.5008 - val_acc: 0.7889
#
# Epoch 00089: val_acc did not improve from 0.81111
# Epoch 90/300
#  - 0s - loss: 0.3558 - acc: 0.8278 - val_loss: 0.5007 - val_acc: 0.8000
#
# Epoch 00090: val_acc did not improve from 0.81111
# Epoch 91/300
#  - 0s - loss: 0.3875 - acc: 0.8222 - val_loss: 0.4896 - val_acc: 0.8000
#
# Epoch 00091: val_acc did not improve from 0.81111
# Epoch 92/300
#  - 0s - loss: 0.3647 - acc: 0.8667 - val_loss: 0.4948 - val_acc: 0.8000
#
# Epoch 00092: val_acc did not improve from 0.81111
# Epoch 93/300
#  - 0s - loss: 0.3022 - acc: 0.8667 - val_loss: 0.4918 - val_acc: 0.8000
#
# Epoch 00093: val_acc did not improve from 0.81111
# Epoch 94/300
#  - 0s - loss: 0.4057 - acc: 0.8028 - val_loss: 0.4951 - val_acc: 0.8000
#
# Epoch 00094: val_acc did not improve from 0.81111
# Epoch 95/300
#  - 0s - loss: 0.3679 - acc: 0.8417 - val_loss: 0.5037 - val_acc: 0.7889
#
# Epoch 00095: val_acc did not improve from 0.81111
# Epoch 96/300
#  - 0s - loss: 0.3484 - acc: 0.8556 - val_loss: 0.4986 - val_acc: 0.7889
#
# Epoch 00096: val_acc did not improve from 0.81111
# Epoch 97/300
#  - 0s - loss: 0.2980 - acc: 0.8833 - val_loss: 0.4958 - val_acc: 0.7889
#
# Epoch 00097: val_acc did not improve from 0.81111
# Epoch 98/300
#  - 0s - loss: 0.3210 - acc: 0.8583 - val_loss: 0.5063 - val_acc: 0.7556
#
# Epoch 00098: val_acc did not improve from 0.81111
# Epoch 99/300
#  - 0s - loss: 0.3607 - acc: 0.8583 - val_loss: 0.5181 - val_acc: 0.7556
#
# Epoch 00099: val_acc did not improve from 0.81111
# Epoch 100/300
#  - 0s - loss: 0.3497 - acc: 0.8500 - val_loss: 0.5166 - val_acc: 0.7667
#
# Epoch 00100: val_acc did not improve from 0.81111
# Epoch 101/300
#  - 0s - loss: 0.3073 - acc: 0.8750 - val_loss: 0.5232 - val_acc: 0.7444
#
# Epoch 00101: val_acc did not improve from 0.81111
# Epoch 102/300
#  - 0s - loss: 0.3166 - acc: 0.8833 - val_loss: 0.5255 - val_acc: 0.7556
#
# Epoch 00102: val_acc did not improve from 0.81111
# Epoch 103/300
#  - 0s - loss: 0.3538 - acc: 0.8444 - val_loss: 0.5383 - val_acc: 0.7556
#
# Epoch 00103: val_acc did not improve from 0.81111
# Epoch 104/300
#  - 0s - loss: 0.2947 - acc: 0.8917 - val_loss: 0.5531 - val_acc: 0.7667
#
# Epoch 00104: val_acc did not improve from 0.81111
# Epoch 105/300
#  - 0s - loss: 0.2994 - acc: 0.8722 - val_loss: 0.5742 - val_acc: 0.7556
#
# Epoch 00105: val_acc did not improve from 0.81111
# Epoch 106/300
#  - 0s - loss: 0.3317 - acc: 0.8778 - val_loss: 0.5480 - val_acc: 0.7667
#
# Epoch 00106: val_acc did not improve from 0.81111
# Epoch 107/300
#  - 0s - loss: 0.2926 - acc: 0.8917 - val_loss: 0.5275 - val_acc: 0.7667
#
# Epoch 00107: val_acc did not improve from 0.81111
# Epoch 108/300
#  - 0s - loss: 0.3147 - acc: 0.8694 - val_loss: 0.5371 - val_acc: 0.7556
#
# Epoch 00108: val_acc did not improve from 0.81111
# Epoch 109/300
#  - 0s - loss: 0.3895 - acc: 0.8111 - val_loss: 0.5388 - val_acc: 0.7667
#
# Epoch 00109: val_acc did not improve from 0.81111
# Epoch 110/300
#  - 0s - loss: 0.3109 - acc: 0.8639 - val_loss: 0.5291 - val_acc: 0.7556
#
# Epoch 00110: val_acc did not improve from 0.81111
# Epoch 111/300
#  - 0s - loss: 0.2828 - acc: 0.8694 - val_loss: 0.4947 - val_acc: 0.7667
# Epoch 00111: val_acc did not improve from 0.81111
# Epoch 112/300
#  - 0s - loss: 0.3331 - acc: 0.8556 - val_loss: 0.4855 - val_acc: 0.7667
#
# Epoch 00112: val_acc did not improve from 0.81111
# Epoch 113/300
#  - 0s - loss: 0.3183 - acc: 0.8750 - val_loss: 0.4974 - val_acc: 0.7667
#
# Epoch 00113: val_acc did not improve from 0.81111
# Epoch 114/300
#  - 0s - loss: 0.2870 - acc: 0.8917 - val_loss: 0.5019 - val_acc: 0.7778
#
# Epoch 00114: val_acc did not improve from 0.81111
# Epoch 115/300
#  - 0s - loss: 0.3036 - acc: 0.8750 - val_loss: 0.5151 - val_acc: 0.7667
#
# Epoch 00115: val_acc did not improve from 0.81111
# Epoch 116/300
#  - 0s - loss: 0.3090 - acc: 0.8500 - val_loss: 0.5257 - val_acc: 0.7667
#
# Epoch 00116: val_acc did not improve from 0.81111
# Epoch 117/300
#  - 0s - loss: 0.3067 - acc: 0.8667 - val_loss: 0.5221 - val_acc: 0.7667
#
# Epoch 00117: val_acc did not improve from 0.81111
# Epoch 118/300
#  - 0s - loss: 0.2806 - acc: 0.8750 - val_loss: 0.5127 - val_acc: 0.7667
#
# Epoch 00118: val_acc did not improve from 0.81111
# Epoch 119/300
#  - 0s - loss: 0.3040 - acc: 0.8667 - val_loss: 0.4985 - val_acc: 0.7778
#
# Epoch 00119: val_acc did not improve from 0.81111
# Epoch 120/300
#  - 0s - loss: 0.2836 - acc: 0.8972 - val_loss: 0.4970 - val_acc: 0.7778
#
# Epoch 00120: val_acc did not improve from 0.81111
# Epoch 121/300
#  - 0s - loss: 0.2889 - acc: 0.8806 - val_loss: 0.5020 - val_acc: 0.7889
#
# Epoch 00121: val_acc did not improve from 0.81111
# Epoch 122/300
#  - 0s - loss: 0.2911 - acc: 0.8833 - val_loss: 0.5046 - val_acc: 0.8000
#
# Epoch 00122: val_acc did not improve from 0.81111
# Epoch 123/300
#  - 0s - loss: 0.2730 - acc: 0.8833 - val_loss: 0.5206 - val_acc: 0.7667
#
# Epoch 00123: val_acc did not improve from 0.81111
# Epoch 124/300
#  - 0s - loss: 0.2653 - acc: 0.8889 - val_loss: 0.5231 - val_acc: 0.7667
#
# Epoch 00124: val_acc did not improve from 0.81111
# Epoch 125/300
#  - 0s - loss: 0.2930 - acc: 0.8750 - val_loss: 0.5271 - val_acc: 0.7556
#
# Epoch 00125: val_acc did not improve from 0.81111
# Epoch 126/300
#  - 0s - loss: 0.2627 - acc: 0.9000 - val_loss: 0.5267 - val_acc: 0.7667
#
# Epoch 00126: val_acc did not improve from 0.81111
# Epoch 127/300
#  - 0s - loss: 0.2704 - acc: 0.9000 - val_loss: 0.5129 - val_acc: 0.7889
#
# Epoch 00127: val_acc did not improve from 0.81111
# Epoch 128/300
#  - 0s - loss: 0.2636 - acc: 0.9000 - val_loss: 0.4994 - val_acc: 0.7667
#
# Epoch 00128: val_acc did not improve from 0.81111
# Epoch 129/300
#  - 0s - loss: 0.2371 - acc: 0.9056 - val_loss: 0.5014 - val_acc: 0.7667
#
# Epoch 00129: val_acc did not improve from 0.81111
# Epoch 130/300
#  - 0s - loss: 0.2362 - acc: 0.9028 - val_loss: 0.5028 - val_acc: 0.7778
#
# Epoch 00130: val_acc did not improve from 0.81111
# Epoch 131/300
#  - 0s - loss: 0.2056 - acc: 0.9444 - val_loss: 0.5200 - val_acc: 0.7444
#
# Epoch 00131: val_acc did not improve from 0.81111
# Epoch 132/300
#  - 0s - loss: 0.2344 - acc: 0.9111 - val_loss: 0.5345 - val_acc: 0.7444
#
# Epoch 00132: val_acc did not improve from 0.81111
# Epoch 133/300
#  - 0s - loss: 0.2906 - acc: 0.8917 - val_loss: 0.5550 - val_acc: 0.7556
#
# Epoch 00133: val_acc did not improve from 0.81111
# Epoch 134/300
#  - 0s - loss: 0.2544 - acc: 0.9083 - val_loss: 0.5491 - val_acc: 0.7667
#
# Epoch 00134: val_acc did not improve from 0.81111
# Epoch 135/300
#  - 0s - loss: 0.2241 - acc: 0.9194 - val_loss: 0.5285 - val_acc: 0.7667
#
# Epoch 00135: val_acc did not improve from 0.81111
# Epoch 136/300
#  - 0s - loss: 0.2162 - acc: 0.9333 - val_loss: 0.5081 - val_acc: 0.7667
#
# Epoch 00136: val_acc did not improve from 0.81111
# Epoch 137/300
#  - 0s - loss: 0.2210 - acc: 0.9194 - val_loss: 0.5300 - val_acc: 0.7667
#
# Epoch 00137: val_acc did not improve from 0.81111
# Epoch 138/300
#  - 0s - loss: 0.2120 - acc: 0.9167 - val_loss: 0.5362 - val_acc: 0.7556
#
# Epoch 00138: val_acc did not improve from 0.81111
# Epoch 139/300
#  - 0s - loss: 0.1939 - acc: 0.9583 - val_loss: 0.5278 - val_acc: 0.7444
#
# Epoch 00139: val_acc did not improve from 0.81111
# Epoch 140/300
#  - 0s - loss: 0.2055 - acc: 0.9306 - val_loss: 0.5207 - val_acc: 0.7778
#
# Epoch 00140: val_acc did not improve from 0.81111
# Epoch 141/300
#  - 0s - loss: 0.2284 - acc: 0.9167 - val_loss: 0.5270 - val_acc: 0.7667
#
# Epoch 00141: val_acc did not improve from 0.81111
# Epoch 142/300
#  - 0s - loss: 0.2032 - acc: 0.9389 - val_loss: 0.5315 - val_acc: 0.7444
#
# Epoch 00142: val_acc did not improve from 0.81111
# Epoch 143/300
#  - 0s - loss: 0.2569 - acc: 0.8806 - val_loss: 0.5431 - val_acc: 0.7333
#
# Epoch 00143: val_acc did not improve from 0.81111
# Epoch 144/300
#  - 0s - loss: 0.1901 - acc: 0.9472 - val_loss: 0.5183 - val_acc: 0.7778
#
# Epoch 00144: val_acc did not improve from 0.81111
# Epoch 145/300
#  - 0s - loss: 0.2078 - acc: 0.9278 - val_loss: 0.5200 - val_acc: 0.7556
#
# Epoch 00145: val_acc did not improve from 0.81111
# Epoch 146/300
#  - 0s - loss: 0.1976 - acc: 0.9306 - val_loss: 0.5296 - val_acc: 0.7667
#
# Epoch 00146: val_acc did not improve from 0.81111
# Epoch 147/300
#  - 0s - loss: 0.2009 - acc: 0.9333 - val_loss: 0.5457 - val_acc: 0.7667
#
# Epoch 00147: val_acc did not improve from 0.81111
# Epoch 148/300
#  - 0s - loss: 0.1957 - acc: 0.9444 - val_loss: 0.5519 - val_acc: 0.7556
#
# Epoch 00148: val_acc did not improve from 0.81111
# Epoch 149/300
#  - 0s - loss: 0.2001 - acc: 0.9389 - val_loss: 0.5396 - val_acc: 0.7333
#
# Epoch 00149: val_acc did not improve from 0.81111
# Epoch 150/300
#  - 0s - loss: 0.2357 - acc: 0.9056 - val_loss: 0.5368 - val_acc: 0.7556
#
# Epoch 00150: val_acc did not improve from 0.81111
# Epoch 151/300
#  - 0s - loss: 0.1708 - acc: 0.9528 - val_loss: 0.5338 - val_acc: 0.7444
#
# Epoch 00151: val_acc did not improve from 0.81111
# Epoch 152/300
#  - 0s - loss: 0.1992 - acc: 0.9472 - val_loss: 0.5223 - val_acc: 0.7667
#
# Epoch 00152: val_acc did not improve from 0.81111
# Epoch 153/300
#  - 0s - loss: 0.1848 - acc: 0.9417 - val_loss: 0.5168 - val_acc: 0.7667
#
# Epoch 00153: val_acc did not improve from 0.81111
# Epoch 154/300
#  - 0s - loss: 0.2015 - acc: 0.9306 - val_loss: 0.5176 - val_acc: 0.7556
#
# Epoch 00154: val_acc did not improve from 0.81111
# Epoch 155/300
#  - 0s - loss: 0.2030 - acc: 0.9222 - val_loss: 0.5041 - val_acc: 0.7556
#
# Epoch 00155: val_acc did not improve from 0.81111
# Epoch 156/300
#  - 0s - loss: 0.1869 - acc: 0.9333 - val_loss: 0.5466 - val_acc: 0.7444
#
# Epoch 00156: val_acc did not improve from 0.81111
# Epoch 157/300
#  - 0s - loss: 0.2168 - acc: 0.9083 - val_loss: 0.5400 - val_acc: 0.7444
#
# Epoch 00157: val_acc did not improve from 0.81111
# Epoch 158/300
#  - 0s - loss: 0.2146 - acc: 0.9222 - val_loss: 0.5429 - val_acc: 0.7333
#
# Epoch 00158: val_acc did not improve from 0.81111
# Epoch 159/300
#  - 0s - loss: 0.1905 - acc: 0.9472 - val_loss: 0.5613 - val_acc: 0.7444
#
# Epoch 00159: val_acc did not improve from 0.81111
# Epoch 160/300
#  - 0s - loss: 0.1987 - acc: 0.9417 - val_loss: 0.5489 - val_acc: 0.7556
#
# Epoch 00160: val_acc did not improve from 0.81111
# Epoch 161/300
#  - 0s - loss: 0.1932 - acc: 0.9278 - val_loss: 0.5354 - val_acc: 0.7667
#
# Epoch 00161: val_acc did not improve from 0.81111
# Epoch 162/300
#  - 0s - loss: 0.1892 - acc: 0.9333 - val_loss: 0.5209 - val_acc: 0.7667
#
# Epoch 00162: val_acc did not improve from 0.81111
# Epoch 163/300
#  - 0s - loss: 0.2044 - acc: 0.9250 - val_loss: 0.5273 - val_acc: 0.7556
#
# Epoch 00163: val_acc did not improve from 0.81111
# Epoch 164/300
#  - 0s - loss: 0.1626 - acc: 0.9639 - val_loss: 0.5253 - val_acc: 0.7778
#
# Epoch 00164: val_acc did not improve from 0.81111
# Epoch 165/300
#  - 0s - loss: 0.1796 - acc: 0.9417 - val_loss: 0.5341 - val_acc: 0.7778
#
# Epoch 00165: val_acc did not improve from 0.81111
# Epoch 166/300
#  - 0s - loss: 0.1786 - acc: 0.9444 - val_loss: 0.5502 - val_acc: 0.7778
#
# Epoch 00166: val_acc did not improve from 0.81111
# Epoch 167/300
#  - 0s - loss: 0.1741 - acc: 0.9389 - val_loss: 0.5452 - val_acc: 0.7889
#
# Epoch 00167: val_acc did not improve from 0.81111
# Epoch 168/300
#  - 0s - loss: 0.1502 - acc: 0.9583 - val_loss: 0.5209 - val_acc: 0.8000
#
# Epoch 00168: val_acc did not improve from 0.81111
# Epoch 169/300
#  - 0s - loss: 0.1548 - acc: 0.9556 - val_loss: 0.5033 - val_acc: 0.7889
#
# Epoch 00169: val_acc did not improve from 0.81111
# Epoch 170/300
#  - 0s - loss: 0.1561 - acc: 0.9583 - val_loss: 0.5078 - val_acc: 0.8000
#
# Epoch 00170: val_acc did not improve from 0.81111
# Epoch 171/300
#  - 0s - loss: 0.1675 - acc: 0.9472 - val_loss: 0.4930 - val_acc: 0.8222
# Epoch 00171: val_acc improved from 0.81111 to 0.82222, saving model to /home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5
# Epoch 172/300
#  - 0s - loss: 0.2085 - acc: 0.9306 - val_loss: 0.4925 - val_acc: 0.8222
#
# Epoch 00172: val_acc did not improve from 0.82222
# Epoch 173/300
#  - 0s - loss: 0.1528 - acc: 0.9583 - val_loss: 0.5077 - val_acc: 0.7889
#
# Epoch 00173: val_acc did not improve from 0.82222
# Epoch 174/300
#  - 0s - loss: 0.1733 - acc: 0.9389 - val_loss: 0.5381 - val_acc: 0.7778
#
# Epoch 00174: val_acc did not improve from 0.82222
# Epoch 175/300
#  - 0s - loss: 0.1592 - acc: 0.9444 - val_loss: 0.5326 - val_acc: 0.7889
#
# Epoch 00175: val_acc did not improve from 0.82222
# Epoch 176/300
#  - 0s - loss: 0.1643 - acc: 0.9528 - val_loss: 0.5516 - val_acc: 0.7889
#
# Epoch 00176: val_acc did not improve from 0.82222
# Epoch 177/300
#  - 0s - loss: 0.1706 - acc: 0.9444 - val_loss: 0.5448 - val_acc: 0.7667
#
# Epoch 00177: val_acc did not improve from 0.82222
# Epoch 178/300
#  - 0s - loss: 0.1455 - acc: 0.9556 - val_loss: 0.5317 - val_acc: 0.7778
#
# Epoch 00178: val_acc did not improve from 0.82222
# Epoch 179/300
#  - 0s - loss: 0.1472 - acc: 0.9639 - val_loss: 0.5328 - val_acc: 0.7778
#
# Epoch 00179: val_acc did not improve from 0.82222
# Epoch 180/300
#  - 0s - loss: 0.1430 - acc: 0.9694 - val_loss: 0.5170 - val_acc: 0.7778
#
# Epoch 00180: val_acc did not improve from 0.82222
# Epoch 181/300
#  - 0s - loss: 0.1314 - acc: 0.9694 - val_loss: 0.5238 - val_acc: 0.7778
#
# Epoch 00181: val_acc did not improve from 0.82222
# Epoch 182/300
#  - 0s - loss: 0.1265 - acc: 0.9639 - val_loss: 0.5230 - val_acc: 0.7667
#
# Epoch 00182: val_acc did not improve from 0.82222
# Epoch 183/300
#  - 0s - loss: 0.1569 - acc: 0.9528 - val_loss: 0.5149 - val_acc: 0.7778
#
# Epoch 00183: val_acc did not improve from 0.82222
# Epoch 184/300
#  - 0s - loss: 0.1480 - acc: 0.9639 - val_loss: 0.5225 - val_acc: 0.7667
#
# Epoch 00184: val_acc did not improve from 0.82222
# Epoch 185/300
#  - 0s - loss: 0.1505 - acc: 0.9472 - val_loss: 0.5557 - val_acc: 0.7556
#
# Epoch 00185: val_acc did not improve from 0.82222
# Epoch 186/300
#  - 0s - loss: 0.1542 - acc: 0.9528 - val_loss: 0.5606 - val_acc: 0.7667
#
# Epoch 00186: val_acc did not improve from 0.82222
# Epoch 187/300
#  - 0s - loss: 0.1412 - acc: 0.9611 - val_loss: 0.5615 - val_acc: 0.7667
#
# Epoch 00187: val_acc did not improve from 0.82222
# Epoch 188/300
#  - 0s - loss: 0.1369 - acc: 0.9694 - val_loss: 0.5488 - val_acc: 0.7778
#
# Epoch 00188: val_acc did not improve from 0.82222
# Epoch 189/300
#  - 0s - loss: 0.1281 - acc: 0.9639 - val_loss: 0.5502 - val_acc: 0.7778
#
# Epoch 00189: val_acc did not improve from 0.82222
# Epoch 190/300
#  - 0s - loss: 0.1596 - acc: 0.9472 - val_loss: 0.5630 - val_acc: 0.7556
#
# Epoch 00190: val_acc did not improve from 0.82222
# Epoch 191/300
#  - 0s - loss: 0.1208 - acc: 0.9667 - val_loss: 0.5599 - val_acc: 0.7667
#
# Epoch 00191: val_acc did not improve from 0.82222
# Epoch 192/300
#  - 0s - loss: 0.1184 - acc: 0.9667 - val_loss: 0.5455 - val_acc: 0.7667
#
# Epoch 00192: val_acc did not improve from 0.82222
# Epoch 193/300
#  - 0s - loss: 0.1332 - acc: 0.9639 - val_loss: 0.5359 - val_acc: 0.7778
#
# Epoch 00193: val_acc did not improve from 0.82222
# Epoch 194/300
#  - 0s - loss: 0.1150 - acc: 0.9806 - val_loss: 0.5406 - val_acc: 0.7778
#
# Epoch 00194: val_acc did not improve from 0.82222
# Epoch 195/300
#  - 0s - loss: 0.1358 - acc: 0.9611 - val_loss: 0.5358 - val_acc: 0.7889
#
# Epoch 00195: val_acc did not improve from 0.82222
# Epoch 196/300
#  - 0s - loss: 0.1230 - acc: 0.9750 - val_loss: 0.5507 - val_acc: 0.7778
#
# Epoch 00196: val_acc did not improve from 0.82222
# Epoch 197/300
#  - 0s - loss: 0.1216 - acc: 0.9694 - val_loss: 0.5288 - val_acc: 0.8000
#
# Epoch 00197: val_acc did not improve from 0.82222
# Epoch 198/300
#  - 0s - loss: 0.1546 - acc: 0.9500 - val_loss: 0.5341 - val_acc: 0.8000
#
# Epoch 00198: val_acc did not improve from 0.82222
# Epoch 199/300
#  - 0s - loss: 0.1275 - acc: 0.9639 - val_loss: 0.5589 - val_acc: 0.7889
#
# Epoch 00199: val_acc did not improve from 0.82222
# Epoch 200/300
#  - 0s - loss: 0.1123 - acc: 0.9722 - val_loss: 0.5696 - val_acc: 0.8000
#
# Epoch 00200: val_acc did not improve from 0.82222
# Epoch 201/300
#  - 0s - loss: 0.1188 - acc: 0.9750 - val_loss: 0.5472 - val_acc: 0.8000
#
# Epoch 00201: val_acc did not improve from 0.82222
# Epoch 202/300
#  - 0s - loss: 0.1164 - acc: 0.9750 - val_loss: 0.5492 - val_acc: 0.7889
#
# Epoch 00202: val_acc did not improve from 0.82222
# Epoch 203/300
#  - 0s - loss: 0.1274 - acc: 0.9583 - val_loss: 0.5493 - val_acc: 0.7889
#
# Epoch 00203: val_acc did not improve from 0.82222
# Epoch 204/300
#  - 0s - loss: 0.1320 - acc: 0.9583 - val_loss: 0.5385 - val_acc: 0.7667
#
# Epoch 00204: val_acc did not improve from 0.82222
# Epoch 205/300
#  - 0s - loss: 0.1194 - acc: 0.9667 - val_loss: 0.5264 - val_acc: 0.7667
#
# Epoch 00205: val_acc did not improve from 0.82222
# Epoch 206/300
#  - 0s - loss: 0.1005 - acc: 0.9750 - val_loss: 0.5475 - val_acc: 0.7889
#
# Epoch 00206: val_acc did not improve from 0.82222
# Epoch 207/300
#  - 0s - loss: 0.1083 - acc: 0.9694 - val_loss: 0.5586 - val_acc: 0.7778
#
# Epoch 00207: val_acc did not improve from 0.82222
# Epoch 208/300
#  - 0s - loss: 0.0988 - acc: 0.9806 - val_loss: 0.5375 - val_acc: 0.7889
#
# Epoch 00208: val_acc did not improve from 0.82222
# Epoch 209/300
#  - 0s - loss: 0.1154 - acc: 0.9639 - val_loss: 0.5302 - val_acc: 0.7778
#
# Epoch 00209: val_acc did not improve from 0.82222
# Epoch 210/300
#  - 0s - loss: 0.1038 - acc: 0.9806 - val_loss: 0.5325 - val_acc: 0.7778
#
# Epoch 00210: val_acc did not improve from 0.82222
# Epoch 211/300
#  - 0s - loss: 0.0986 - acc: 0.9722 - val_loss: 0.5497 - val_acc: 0.7778
#
# Epoch 00211: val_acc did not improve from 0.82222
# Epoch 212/300
#  - 0s - loss: 0.1225 - acc: 0.9611 - val_loss: 0.5422 - val_acc: 0.7778
#
# Epoch 00212: val_acc did not improve from 0.82222

# %%
# print(np.array(history.losses))
import matplotlib.pyplot as plt
# %matplotlib inline

f, axs = plt.subplots(1,3,figsize=(15,5))

loss = train_history.history['loss']
val_loss = train_history.history['val_loss']
plt.subplot(121)
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['loss', 'val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(122)
plt.title('Accuracy')
plt.plot(train_history.history['acc'])
plt.plot(train_history.history['val_acc'])
plt.legend(['acc', 'val_acc'])

# %%
model.load_weights('/home/amplifier/home/NEW_DL/weights/IMG_net_2_wts.h5')
# let's predict a TRAINING sammple:
decoded_train = model.predict(x_train)
decoded_test = model.predict(x_test)
print(decoded_train.shape)
print(decoded_test.shape)

# now test sample by sample
cor_test = []
L = x_test.shape
for sample_no in range(x_test.shape[0]):
    pred = model.predict(np.expand_dims(x_test[sample_no],0))
    if ((pred[0][0]<pred[0][1]) and (y_test[sample_no,0] < y_test[sample_no,1]) or
       ((pred[0][0]>pred[0][1]) and (y_test[sample_no,0] > y_test[sample_no,1]))):
        cor_test.append(1)
    else:
        cor_test.append(0)

cor_train = []
L = x_train.shape
for sample_no in range(x_train.shape[0]):
    pred = model.predict(np.expand_dims(x_train[sample_no],0))
    if ((pred[0][0]<pred[0][1]) and (y_train[sample_no,0] < y_train[sample_no,1]) or
       ((pred[0][0]>pred[0][1]) and (y_train[sample_no,0] > y_train[sample_no,1]))):
        cor_train.append(1)
    else:
        cor_train.append(0)

# Report accuracies
print('Accuracy on the test data:', np.mean(cor_test))
print('Accuracy on the training data:', np.mean(cor_train))
# Out:
# (360, 2)
# (90, 2)
# Accuracy on the test data: 0.8222222222222222
# Accuracy on the training data: 1.0

# %%
# save cor_test as csv for future analysis:
import csv
with open('img_test.csv', 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(cor_test)

# %%
file = '1+2, see desc.'

# %%
import pandas as pd
df_ = pd.DataFrame(columns=['algorithm',
                           'SHUFFLE',
                           'BATCH_SIZE',
                           'TEST_TRAIN',
                           'DS_FREQ',
                           'n_bins',
                           'RESIZE',
                           'width',
                           'height',
                           'SENSITIVITY',
                           'dataset',
                           'val_acc',
                           'acc'])

df_.loc[0] = ['TOPO',
              SHUFFLE,
              BATCH_SIZE,
              TEST_TRAIN,
              DS_FREQ,
              n_bins,
              RESIZE,
              width,
              height,
              str(knockouts),
              file,
              np.mean(cor_test),
              np.mean(cor_train)]
# df.to_csv('/home/amplifier/home/NEW_DL/weights/blank_document.csv', index=False)
df = pd.read_csv('/home/amplifier/home/NEW_DL/weights/performances.csv')
df = df.append(df_, ignore_index=True)
df.drop_duplicates(subset=None, keep='first', inplace=True)
df.to_csv('/home/amplifier/home/NEW_DL/weights/performances.csv', index=False)
df = pd.read_csv('/home/amplifier/home/NEW_DL/weights/performances.csv')
display(df)
# Out:
#    algorithm  SHUFFLE  BATCH_SIZE  TEST_TRAIN  DS_FREQ  n_bins  RESIZE  width  \
# 0       TOPO    False          20         0.2        1       8       1     15
# 1       TOPO    False          20         0.2        1       8       1     15
# 2       TOPO    False          20         0.2        1       8       1     15
# 3       TOPO    False          20         0.2        1       8       1     15
# 4       TOPO    False          20         0.2        1       8       1     15
# 5       TOPO    False          20         0.2        1       8       1     15
# 6       TOPO    False          20         0.2        1       8       1     15
# 7       TOPO    False          20         0.2        1       8       1     15
# 8       TOPO    False          20         0.2        1       8       1     15
# 9       TOPO    False          20         0.2        1       8       1     15
# 10      TOPO    False          20         0.2        1       8       1     15
# 11      TOPO    False          20         0.2        1       8       1     15
# 12      TOPO    False          20         0.2        1       8       1     15
# 13      TOPO    False          20         0.2        1       8       1     15
# 14      TOPO    False          20         0.2        1       8       1     15
# 15      TOPO    False          20         0.2        1       8       1     15
# 16      TOPO    False          20         0.2        1       8       1     15
# 17      TOPO    False          20         0.2        1       8       1     15
# 18      TOPO    False          20         0.2        1       8       1     15
#
#     height SENSITIVITY                                            dataset  \
# 0       15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 1       15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 2       15           1  EEG_ICA(-123_ICs)+proc_AUD_101_192_Merged456.m...
# 3       15           1  Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, D...
# 4       15           1  Merged123_1_64_ICA(-eyes)AUDpreproc.mat, DS2=6...
# 5       15           1  Merged123_75_134_ICA(-eyes)AUDpreproc.mat, DS2...
# 6       15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 7       15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 8       15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 9       15           2  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 10      15           3  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 11      15           3  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 12      15           3  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 13      15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 14      15           1  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 15      15   [1, 2, 3]  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 16      15   [1, 2, 3]  Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS...
# 17      15   [0, 1, 2]                                     1+2, see desc.
# 18      15   [0, 1, 2]                                     1+2, see desc.
#
#      val_acc       acc
# 0   0.766667  0.961111
# 1   0.788889  0.805556
# 2   0.580645  0.973118
# 3   0.800000  0.963889
# 4   0.666667  0.881944
# 5   0.591716  0.599702
# 6   0.722222  0.591667
# 7   0.755556  0.655556
# 8   0.755556  0.666667
# 9   0.777778  0.708333
# 10  0.777778  0.980556
# 11  0.755556  0.725000
# 12  0.722222  0.969444
# 13  0.800000  0.733333
# 14  0.766667  0.738889
# 15  0.788889  0.616667
# 16  0.788889  0.666667
# 17  0.787879  0.741477
# 18  0.688889  0.773611

# %%
# # to CLEAR all the data in the dataframe and save
# df = df[:0]
# df.to_csv('/home/amplifier/home/NEW_DL/weights/performances.csv', index=False)
# df.head()

# df.drop_duplicates(subset=None, keep='first', inplace=True)
# df.head()

# %%
for sample_no in range(70):
    pred = model.predict(np.expand_dims(x_test[sample_no],0))
    print('Sample:', sample_no, 'Prediction:', pred, 'Ground Truth', y_test[sample_no], q_test[sample_no])
sample_no = 2

plt.imshow(x_test[sample_no,:,:,2].astype('float64'))
# Out:
# Sample: 0 Prediction: [[ 0.96013433  0.03986574]] Ground Truth [ 0.  1.] right
# Sample: 1 Prediction: [[ 0.25404075  0.74595928]] Ground Truth [ 0.  1.] right
# Sample: 2 Prediction: [[ 0.32668161  0.67331839]] Ground Truth [ 0.  1.] right
# Sample: 3 Prediction: [[ 0.74391818  0.25608185]] Ground Truth [ 0.  1.] right
# Sample: 4 Prediction: [[ 0.60861325  0.39138672]] Ground Truth [ 0.  1.] right
# Sample: 5 Prediction: [[ 0.3831735   0.61682653]] Ground Truth [ 0.  1.] right
# Sample: 6 Prediction: [[ 0.49828056  0.50171942]] Ground Truth [ 0.  1.] right
# Sample: 7 Prediction: [[ 0.41862848  0.58137155]] Ground Truth [ 0.  1.] right
# Sample: 8 Prediction: [[ 0.35809729  0.64190269]] Ground Truth [ 0.  1.] right
# Sample: 9 Prediction: [[ 0.47699139  0.52300864]] Ground Truth [ 0.  1.] right
# Sample: 10 Prediction: [[ 0.37415457  0.62584543]] Ground Truth [ 0.  1.] right
# Sample: 11 Prediction: [[ 0.39874229  0.60125768]] Ground Truth [ 0.  1.] right
# Sample: 12 Prediction: [[ 0.44023103  0.55976897]] Ground Truth [ 0.  1.] right
# Sample: 13 Prediction: [[ 0.44007784  0.55992216]] Ground Truth [ 0.  1.] right
# Sample: 14 Prediction: [[ 0.58019108  0.41980895]] Ground Truth [ 0.  1.] right
# Sample: 15 Prediction: [[ 0.5972892   0.40271077]] Ground Truth [ 1.  0.] left
# Sample: 16 Prediction: [[ 0.38457316  0.6154269 ]] Ground Truth [ 1.  0.] left
# Sample: 17 Prediction: [[ 0.635369    0.36463097]] Ground Truth [ 1.  0.] left
# Sample: 18 Prediction: [[ 0.48101315  0.51898682]] Ground Truth [ 1.  0.] left
# Sample: 19 Prediction: [[ 0.7774868   0.22251318]] Ground Truth [ 1.  0.] left
# Sample: 20 Prediction: [[ 0.66724747  0.33275253]] Ground Truth [ 1.  0.] left
# Sample: 21 Prediction: [[ 0.57681233  0.42318767]] Ground Truth [ 1.  0.] left
# Sample: 22 Prediction: [[ 0.65336633  0.34663364]] Ground Truth [ 1.  0.] left
# Sample: 23 Prediction: [[ 0.55167353  0.44832647]] Ground Truth [ 1.  0.] left
# Sample: 24 Prediction: [[ 0.61871529  0.38128471]] Ground Truth [ 1.  0.] left
# Sample: 25 Prediction: [[ 0.70293671  0.29706326]] Ground Truth [ 1.  0.] left
# Sample: 26 Prediction: [[ 0.8275004  0.1724996]] Ground Truth [ 1.  0.] left
# Sample: 27 Prediction: [[ 0.91670561  0.08329436]] Ground Truth [ 1.  0.] left
# Sample: 28 Prediction: [[ 0.58379686  0.41620314]] Ground Truth [ 1.  0.] left
# Sample: 29 Prediction: [[ 0.54316795  0.45683205]] Ground Truth [ 1.  0.] left
# Sample: 30 Prediction: [[ 0.46432355  0.53567642]] Ground Truth [ 0.  1.] right
# Sample: 31 Prediction: [[ 0.48211145  0.51788861]] Ground Truth [ 0.  1.] right
# Sample: 32 Prediction: [[ 0.21449119  0.78550881]] Ground Truth [ 0.  1.] right
# Sample: 33 Prediction: [[ 0.21206328  0.78793675]] Ground Truth [ 0.  1.] right
# Sample: 34 Prediction: [[ 0.22660996  0.77339   ]] Ground Truth [ 0.  1.] right
# Sample: 35 Prediction: [[ 0.46444872  0.53555125]] Ground Truth [ 0.  1.] right
# Sample: 36 Prediction: [[ 0.69434208  0.30565789]] Ground Truth [ 0.  1.] right
# Sample: 37 Prediction: [[ 0.24021384  0.75978613]] Ground Truth [ 0.  1.] right
# Sample: 38 Prediction: [[ 0.53315288  0.46684715]] Ground Truth [ 0.  1.] right
# Sample: 39 Prediction: [[ 0.51542366  0.48457634]] Ground Truth [ 0.  1.] right
# Sample: 40 Prediction: [[ 0.40901107  0.59098893]] Ground Truth [ 0.  1.] right
# Sample: 41 Prediction: [[ 0.86995429  0.13004577]] Ground Truth [ 0.  1.] right
# Sample: 42 Prediction: [[ 0.40727648  0.59272355]] Ground Truth [ 0.  1.] right
# Sample: 43 Prediction: [[ 0.64499575  0.35500422]] Ground Truth [ 0.  1.] right
# Sample: 44 Prediction: [[ 0.24289264  0.75710738]] Ground Truth [ 0.  1.] right
# Sample: 45 Prediction: [[ 0.5658223   0.43417764]] Ground Truth [ 1.  0.] left
# Sample: 46 Prediction: [[ 0.39136311  0.60863686]] Ground Truth [ 1.  0.] left
# Sample: 47 Prediction: [[ 0.40332261  0.59667742]] Ground Truth [ 1.  0.] left
# Sample: 48 Prediction: [[ 0.50617278  0.49382722]] Ground Truth [ 1.  0.] left
# Sample: 49 Prediction: [[ 0.57524401  0.42475599]] Ground Truth [ 1.  0.] left
# Sample: 50 Prediction: [[ 0.5554865   0.44451353]] Ground Truth [ 1.  0.] left
# Sample: 51 Prediction: [[ 0.7292304  0.2707696]] Ground Truth [ 1.  0.] left
# Sample: 52 Prediction: [[ 0.5645346   0.43546537]] Ground Truth [ 1.  0.] left
# Sample: 53 Prediction: [[ 0.52866584  0.47133416]] Ground Truth [ 1.  0.] left
# Sample: 54 Prediction: [[ 0.8364619   0.16353813]] Ground Truth [ 1.  0.] left
# Sample: 55 Prediction: [[ 0.63456202  0.36543792]] Ground Truth [ 1.  0.] left
# Sample: 56 Prediction: [[ 0.69037157  0.30962849]] Ground Truth [ 1.  0.] left
# Sample: 57 Prediction: [[ 0.58467048  0.41532946]] Ground Truth [ 1.  0.] left
# Sample: 58 Prediction: [[ 0.64185321  0.35814676]] Ground Truth [ 1.  0.] left
# Sample: 59 Prediction: [[ 0.60528386  0.39471614]] Ground Truth [ 1.  0.] left
# Sample: 60 Prediction: [[ 0.43205687  0.56794316]] Ground Truth [ 0.  1.] right
# Sample: 61 Prediction: [[ 0.43844175  0.56155825]] Ground Truth [ 0.  1.] right
# Sample: 62 Prediction: [[ 0.54402059  0.45597941]] Ground Truth [ 0.  1.] right
# Sample: 63 Prediction: [[ 0.28261474  0.71738523]] Ground Truth [ 0.  1.] right
# Sample: 64 Prediction: [[ 0.58668691  0.41331312]] Ground Truth [ 0.  1.] right
# Sample: 65 Prediction: [[ 0.57500339  0.42499664]] Ground Truth [ 0.  1.] right
# Sample: 66 Prediction: [[ 0.45714927  0.54285073]] Ground Truth [ 0.  1.] right
# Sample: 67 Prediction: [[ 0.70555103  0.29444894]] Ground Truth [ 0.  1.] right
# Sample: 68 Prediction: [[ 0.38692731  0.61307275]] Ground Truth [ 0.  1.] right
# Sample: 69 Prediction: [[ 0.43439525  0.56560475]] Ground Truth [ 0.  1.] right

# %%
sample_nos = [2, 30]
I = 2
J = x_test.shape[3]
c = 0
fig, axs = plt.subplots(I,J)
fig.set_size_inches(18.5, 10.5)
axs = axs.ravel()
for i in range(I):
    for j in range(J):
        axs[c].imshow(x_test[sample_nos[i],:,:,j].astype('float64'))
        axs[c].get_xaxis().set_visible(False)
        axs[c].get_yaxis().set_visible(False)        
        axs[c].set_title('Sample number ' + str(sample_nos[i]) + ' (' + q_test[sample_nos[i]] + '), Freq. band ' + str(j+1))
        c = c + 1
plt.suptitle('Topographies ', fontsize=26)
# Out:
# Text(0.5,0.98,'Topographies ')

# %%
avg_right = np.zeros([height, width, x_test.shape[3]])
avg_left = np.zeros([height, width, x_test.shape[3]])

for b in range(x_test.shape[3]):
    avg_right[:,:,b] = np.mean(x_test[np.array(find_right(q_test, label='right')),:,:,b],axis=0)
    avg_left[:,:,b] = np.mean(x_test[np.array(find_right(q_test, label='left')),:,:,b],axis=0)

I = x_test.shape[3]
J = 2

fig, axs = plt.subplots(I,J)
fig.set_size_inches(18.5, 10.5)
axs = axs.ravel()

c = 0
for b in range(x_test.shape[3]):
    axs[c].imshow(avg_left[:,:,b].astype('float64'))
    axs[c].set_title('Average Left trials')
    c = c + 1
    axs[c].imshow(avg_right[:,:,b].astype('float64'))
    axs[c].set_title('Average Right trials')
    c = c + 1
#         axs[c].get_xaxis().set_visible(False)
#         axs[c].get_yaxis().set_visible(False)        
#         axs[c].set_title('Sample number ' + str(sample_nos[i]) + ' (' + q_test[sample_nos[i]] + '), Freq. band ' + str(j+1))
plt.tight_layout()
plt.suptitle('Topographies Averaged within Classes ', fontsize=26)
# Out:
# Text(0.5,0.98,'Topographies Averaged within Classes ')
