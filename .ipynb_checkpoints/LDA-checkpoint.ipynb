# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2], [5,1]])
y = np.array([1, 1, 1, 2, 2, 2, 1])
c = ('b','b', 'b', 'r','r','r','b')
clf = LinearDiscriminantAnalysis()
clf.fit(X, y)


print(clf.predict([[-0.8, -1]]))
plt.scatter(X[:,0],X[:,1], c=y)

xx = np.linspace(-3,3,100)
coeff = clf.coef_
yy = (-coeff[0,0]*xx-clf.intercept_)/coeff[0,1]
plt.plot(xx,yy)
# Out:
# [1]

# %%
print(clf.coef_)
print(clf.intercept_)
# Out:
# [[  4.61511045e-15   8.00000000e+00]]
# [ 0.]

# %%
Ax + By + C = 0
y = (-Ax-C)/B

# %%
xx = np.linspace(-3,3,100)
coeff = clf.coef_

yy = (-coeff[0,0]*xx-clf.intercept_)/coeff[0,1]

# %%
plt.plot(xx,yy)
