# %%
# we first define the autoencoder's architecture:

# make sure you don't hog all the video memory
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
from keras import backend as K
K.set_session(sess)
###################################

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from keras.models import Model
from keras.models import load_model
from keras.callbacks import TensorBoard

import numpy as np
import matplotlib.pyplot as plt

def conv_net():
    input_img = Input(shape=(60, 800, 1))  # adapt this if using `channels_first` image data format   
    e1 = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
    e2 = MaxPooling2D((2, 1), padding='same')(e1)
    e2b = BatchNormalization(axis=1)(e2)
    e2a = Dropout(0.2)(e2b)
    e3 = Conv2D(32, (3, 3), activation='relu', padding='same')(e2a)
    e4 = MaxPooling2D((3, 1), padding='same')(e3)
    e4b = BatchNormalization(axis=1)(e4)
    e4a = Dropout(0.4)(e4b)
    e5 = Conv2D(64, (3, 3), activation='relu', padding='same')(e4a)
    e6 = MaxPooling2D((2, 1), padding='same')(e5)
    e6b = BatchNormalization(axis=1)(e6)
    e6a = Dropout(0.7)(e6b)
    e7 = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(e6a)
    e8 = MaxPooling2D((5, 1), padding='same')(e7)
    return Model(input_img, e8)
# Out:
# Using TensorFlow backend.

# %%
# define input to the model:
x = Input(shape=(60, 800, 1))

# make the model:
model = conv_net()

# compile the model:
model.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
# model.load_weights('/home/amplifier/home/models/EEGnet.h5')

# %%
# SEE INSIDE THE MODEL:
# conv_net().summary() #or
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 60, 800, 1)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 60, 800, 16)       160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 800, 16)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 800, 16)       120
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 800, 16)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 800, 32)       4640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 10, 800, 32)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 10, 800, 32)       40
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10, 800, 32)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 800, 64)       18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 800, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 800, 64)        20
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 800, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 800, 1)         577
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 800, 1)         0
# =================================================================
# Total params: 24,053
# Trainable params: 23,963
# Non-trainable params: 90
# _________________________________________________________________

# %%
# get the Dataset:

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import scipy.io as sio

# load data from the .mat file:
# mat_contents = sio.loadmat('EEG_big.mat') # (EEG_data.mat')
mat_contents = sio.loadmat('EEG_big4CNN.mat')
X = mat_contents['X']
Y = mat_contents['Y']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)
print('Original data type:', x_train.dtype)

# convert to float64 for numerical stability:
x_train = x_train.astype('float64')
y_train = y_train.astype('float64')
x_test = x_test.astype('float64')
y_test = y_test.astype('float64')

# normalize to unit variance and zero mean:
for i in range(x_train.shape[0]):
    x_train[i,:,:] = preprocessing.scale(x_train[i,:,:], axis=1)
    x_train[i,:,:] = preprocessing.minmax_scale(x_train[i,:,:], axis=1)
    y_train[i,:] = preprocessing.scale(y_train[i,:], axis=0)
    y_train[i,:] = preprocessing.minmax_scale(y_train[i,:], axis=0)

for i in range(x_test.shape[0]):
    x_test[i,:,:] = preprocessing.scale(x_test[i,:,:], axis=1)
    x_test[i,:,:] = preprocessing.minmax_scale(x_test[i,:,:], axis=1)
    y_test[i,:] = preprocessing.scale(y_test[i,:], axis=0)
    y_test[i,:] = preprocessing.minmax_scale(y_test[i,:], axis=0)

# ensure the tensors are sized right:
x_train = np.expand_dims(x_train,3)
x_test = np.expand_dims(x_test,3)
y_test = np.expand_dims(y_test,1)
y_test = y_test[:,:,:,None]
y_train = np.expand_dims(y_train,1)
y_train = y_train[:,:,:,None]

# convert to float16 to save space:
x_train = x_train.astype('float16')
y_train = y_train.astype('float16')
x_test = x_test.astype('float16')
y_test = y_test.astype('float16')
print('Normalized data type:', x_train.dtype)

print('test input shape', x_test.shape, "Nomralized MEAN:", np.mean(x_test), "min", np.min(x_test),"max", np.max(x_test))
print('train input shape', x_train.shape, "Nomralized MEAN:", np.mean(x_train), "min", np.min(x_train),"max", np.max(x_train))

print('test labels shape', y_test.shape, "Nomralized MEAN:", np.mean(y_test), "min", np.min(y_test),"max", np.max(y_test))
print('train labels shape', y_train.shape, "Nomralized MEAN:", np.mean(y_train), "min", np.min(y_train),"max", np.max(y_train))
# Out:
# Original data type: float32
# Normalized data type: float16
# test input shape (181, 60, 800, 1) Nomralized MEAN: 0.51855 min 0.0 max 1.0
# train input shape (724, 60, 800, 1) Nomralized MEAN: 0.51709 min 0.0 max 1.0
# test labels shape (181, 1, 800, 1) Nomralized MEAN: 0.28467 min 0.0 max 1.0
# train labels shape (724, 1, 800, 1) Nomralized MEAN: 0.28369 min 0.0 max 1.0

# %%
# inspect channel ___ sample
chan = 30
samp = 12
# %matplotlib inline
plt.plot(range(0, 800), x_test[samp, chan,:,0], range(0,800), y_test[samp,0,:,0])
ax = plt.gca()
ax.set_title("Channels 11 in test samples 6 and 16")
# Out:
# Text(0.5,1,'Channels 11 in test samples 6 and 16')

# %%
# Training time!
# Try 20 epochs using batch size = 3, then switch to 4
model.fit(x_train, y_train,
                epochs=1000,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, y_test),
                callbacks=[TensorBoard(log_dir='/home/amplifier/home/CNN_stim')])

# save the entire model and the weights after the training:
model.save('/home/amplifier/home/models/EEGnet.h5')
model.save_weights('/home/amplifier/home/weights/EEGnet_weights.h5')

# %%
# let's predict a TRAINING sammple:
decoded_train = model.predict(x_train)
decoded_test = model.predict(x_test)
print(decoded_train.shape)
print(decoded_test.shape)
# Out:
# (724, 1, 800, 1)
# (181, 1, 800, 1)

# %%
reconstruct_training_sample = False
samp = 1

from scipy.stats import pearsonr
# now let's see how the model performs:

if (reconstruct_training_sample==True):
    reconst = decoded_train[samp,:,:,:].reshape(800,1)
    orig = y_train[samp,:,:,:].reshape(800,1)
    R,p = pearsonr(reconst, orig)
    title = "Reconstructed input based on TRAINING data, " + "Corr"+ str(R) + ", P-value" + str(p)
else:
    reconst = decoded_test[samp,:,:,:].reshape(800,1)
    orig = y_test[samp,:,:,:].reshape(800,1)
    R,p = pearsonr(reconst, orig)
    title = "Reconstructed input based on TEST data, " + "Corr"+ str(R) + ", P-value" + str(p)


print("Pearson's R:", R, "p-value", p)
# %matplotlib inline
plt.subplot(211)
plt.plot(reconst)
ax = plt.gca()
ax.set_title(title)
plt.subplot(212)
plt.plot(orig)
ax = plt.gca()
ax.set_title("Original")
# Out:
# Pearson's R: [-0.02939709] p-value [ 0.40633321]
# Text(0.5,1,'Original')

# %%
R,p = pearsonr(reconst, orig)

# %%
print(R)
# Out:
# [-0.04483732]
