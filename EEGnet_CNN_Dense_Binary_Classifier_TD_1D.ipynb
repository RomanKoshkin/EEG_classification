# %%
# file = 'EEG_big.mat'
# file = 'EEG_big4CNN.mat'
# file = 'EEG_big4CNN_1subj.mat'
# file = 'KOS_100Hz_noICA->0.5-38Hz,Env=1.mat'
# file = 'Merged123->0.5-38Hz,Env=1.mat'

# file = 'KOS_100Hz_ICA->0.5-38Hz,Env=1.mat')
# file = 'Merged123->1-48Hz,Env=1.mat'

# file = 'BCI_TD.mat'

# file = 'BCI_0101T_TD.mat'
# file = 'BCI_0202T_TD.mat'
# file = 'BCI_0303T_TD.mat'
# file = 'BCI_0403T_TD.mat'
# file = 'BCI_0503T_TD.mat'
# file = 'BCI_0603T_TD.mat'
# file = 'BCI_0703T_TD.mat'
# file = 'BCI_0801T_TD.mat'

# file = 'BCI_FD.mat'

# file = 'ks.mat'
# file = 'ks_FD.mat'
# file = 'ks_2TD.mat'
# file = 'ksenia2_long_chunked.mat'

# file = 'BCI_FD_fullspectrum.mat'
# file = 'BCI_FD_lowspectrum.mat'
# file = 'KOS_100Hz_ICA->1-38Hz,Env=1_FD.mat'
# file = 'Merged123->1-100Hz,Env=1_FD'
# file = 'Merged123->1-47Hz,Env=1_FD.mat'
# file = 'Merged123->15-47Hz,Env=1_TD.mat'
# file = 'Merged123->15-47Hz,Env=1_TD5_64_.mat'
# file = 'Merged123->75-134Hz,Env=1_TD.mat'
# file = 'Merged123->2-30Hz,Env=1_TD5_64_.mat'

# file = 'Merged456->2-30Hz,Env=1_TD1_94_.mat'                # 0.71
# file = 'Merged456->2-30Hz,Env=1_TD101_192_.mat'             # 0.60
# file = 'Merged456->2-30Hz,Env=1_TD197_289_.mat'             # 0.85

# file = 'DAS_1_ica.mat, DS2=200Hz, FIR=1-60Hz, centnorm=1, Env=1, ICA, 1-124.mat' # 0.53 
# file = 'Merged456_197-298_protocol_1.set, DS2=250Hz, FIR=1-47Hz, centnorm=0, Env=0, ICA, 1-95.mat'
# file = 'Merged456_197-298_protocol_1.set, DS2=250Hz, FIR=1-47Hz, centnorm=0, Env=0, NOICA, 1-95.mat'



# file = 'DAS_CH.mat, DS2=250Hz, FIR=1-30Hz, centnorm=1, Env=1, TD, 1-124.mat' # 0.65
# file = 'DAS_CH.mat, DS2=250Hz, FIR=1-38Hz, centnorm=1, Env=1, TD, 1-124.mat'
# file = 'DAS_CH.mat, DS2=250Hz, FIR=1-47Hz, centnorm=1, Env=1, TD, 1-124.mat'   # 0.60

# file = 'Merged123_1_64_ICA(-eyes)AUDpreproc.mat, DS2=64Hz, FIR=1-9Hz, centnorm=1, Env=1, TD, 1-90.mat'
# file = 'Merged123_1_64_ICA(-eyes)AUDpreproc.mat, DS2=250Hz, FIR=2-30Hz, centnorm=1, Env=1, TD, 1-90.mat' # 0.61
# file = 'Merged123_1_64_ICA(-eyes)AUDpreproc.mat, DS2=250Hz, FIR=2-30Hz, centnorm=1, step=1, win=2, TD, 1-90.mat' #0.61

# file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=250Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-93.mat' # 0.76
# file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-93.mat'

# file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=4, TD, 1-93.mat' #0.7
# file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=1-30Hz, centnorm=1, step=2, win=2, TD, 1-93.mat' #0.60
# file = 'Merged456-197-289_ICA(-eyes)+AUDpreproc.mat, DS2=64Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-93.mat' #0.75(unstable)

file = 'Merged456-197-289_ICA(ANDeyes)+AUDpreproc.mat, DS2=64Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-93.mat' #0.86
# file = 'Merged456-197-289_ICA(ANDeyes)+AUDpreproc.mat, DS2=250Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-93.mat' #0.89

# file = 'Merged456-1-94_ICA(-2,3ICs)+AUDpreproc.mat, DS2=64Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-95.mat' #0.65
# file = 'EEG_ICA(-123_ICs)+proc_AUD_101_192_Merged456.mat, DS2=64Hz, FIR=2-30Hz, centnorm=1, step=2, win=2, TD, 1-92.mat' #0.59

# file = 'NeoRec_2018-05-08_21-47-10+ICA(-IC1)preproc_aud.mat, DS2=64Hz, FIR=1-40Hz, centnorm=1, Env=1, TD, 1-123.mat' # 0.63
# file = 'NeoRec_2018-05-08_21-47-10+ICA.mat, DS2=64Hz, FIR=1-40Hz, centnorm=1, Env=1, TD, 1-123.mat'
# file = 'NeoRec_2018-05-08_16-52-10_-eyes.mat, DS2=64Hz, FIR=1-40Hz, centnorm=1, Env=1, TD, 1-124.mat' 
# file = 'NeoRec_2018-05-08_16-52-10_-eyes.mat, DS2=128Hz, FIR=1-40Hz, centnorm=1, Env=1, TD, 1-124.mat'
# file = 'NeoRec_2018-05-08_16-52-10.mat, DS2=64Hz, FIR=1-40Hz, centnorm=1, Env=1, TD, 1-124.mat'

SHUFFLE = False
BATCH_SIZE = 20
TEST_TRAIN = 0.25

KERNEL_SIZE = (26, 13, 6, 2)
POOL_SIZE = (2,2,2,2)
N_KERNELS = (20,40,80,160)
# N_KERNELS = (10,20,40,80)


# ДОБИТЬСЯ ХОРОШЕЙ ТОЧНОСТИ НА 250 Гц (без ICA)
# снижать Fs
# reconstruction on 1-9, new preproc

# %%
# get the Dataset:
import scipy.io as sio
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

path = '/home/amplifier/home/DATASETS/' + file
mat_contents = sio.loadmat(path)
X = mat_contents['X']
Y = mat_contents['Z']

if X.shape[1]<X.shape[2]:
    X = np.transpose(X,[0,2,1])

if Y.shape[1] > Y.shape[0]:
    Y = Y.T
    
print('Original data shape:', X.shape)
print('Original labels shape:', Y.shape)

# verify that the model REALLY finds a mapping between the input and the labels. If we get
# our accuracy by chance, then we should get the same accuracy on a permuted dataset:
# Y = np.random.permutation(Y)


# winsize = mat_contents['winsize']
# stepsize = mat_contents['stepsize']
# trial_len = mat_contents['trial_len']
# low_cutoff = mat_contents['low_cutoff']
# high_cutoff = mat_contents['high_cutoff']
# source = mat_contents['filein']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=TEST_TRAIN, shuffle=SHUFFLE)
print('Original data type:', x_train.dtype)

# convert to float64 for numerical stability:
x_train = x_train.astype('float64')
y_train = y_train.astype('float64')
x_test = x_test.astype('float64')
y_test = y_test.astype('float64')

# one hot encode the labels:
onehot_encoder = preprocessing.OneHotEncoder(sparse=False)
y_train = onehot_encoder.fit_transform(y_train)
y_test = onehot_encoder.fit_transform(y_test)

# convert to float16 to save space:
x_train = x_train.astype('float16')
y_train = y_train.astype('float16')
x_test = x_test.astype('float16')
y_test = y_test.astype('float16')
print('Normalized data type:', x_train.dtype)

leng = X.shape[1] # if you work in the FD, this is the height of the sample time-frequency image, othewise EEG channels
chan = X.shape[2] # if you work in the FD, this is the width of the sample time-frequency image, othewise time samples of EEG signal

if len(X.shape)==3:
    streams = 1 # this is EEG channels if you work with frequency domain, in the TD streams = 1
if len(X.shape)==4:
    streams = X.shape[3] # this is EEG channels if you work with frequency domain, in the TD streams = 1


print('test input shape', x_test.shape, "Nomralized MEAN:", np.mean(x_test), "min", np.min(x_test),"max", np.max(x_test))
print('train input shape', x_train.shape, "Nomralized MEAN:", np.mean(x_train), "min", np.min(x_train),"max", np.max(x_train))

print('test labels shape', y_test.shape, "Nomralized MEAN:", np.mean(y_test), "min", np.min(y_test),"max", np.max(y_test))
print('train labels shape', y_train.shape, "Nomralized MEAN:", np.mean(y_train), "min", np.min(y_train),"max", np.max(y_train))

# print('Window length', winsize)
# print('Step size:', stepsize)
# print('Trial length:', trial_len)
# Out:
# Original data shape: (450, 128, 60)
# Original labels shape: (450, 1)
# Original data type: float32
# Normalized data type: float16
# test input shape (113, 128, 60) Nomralized MEAN: 0.00010717 min -4.77 max 4.902
# train input shape (337, 128, 60) Nomralized MEAN: 6.21e-05 min -10.18 max 8.86
# test labels shape (113, 2) Nomralized MEAN: 0.5 min 0.0 max 1.0
# train labels shape (337, 2) Nomralized MEAN: 0.5 min 0.0 max 1.0

# %%
# we first define the autoencoder's architecture:

# make sure you don't hog all the video memory
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
from keras import backend as K
K.set_session(sess)
###################################

from keras.layers import Input, Dense, Conv1D, MaxPooling1D, SeparableConv1D, Dropout, BatchNormalization, Flatten, ELU, Activation
from keras.models import Model
from keras.models import load_model
from keras.callbacks import TensorBoard, EarlyStopping
from keras import optimizers
from keras.initializers import Orthogonal as orth

import numpy as np
import matplotlib.pyplot as plt

def activation():
    return ELU(alpha=1.0) # Activation('relu') #

def conv_net(leng):
    input_img = Input(shape=(leng, chan))  # adapt this if using `channels_first` image
    
    block1 = SeparableConv1D(3, KERNEL_SIZE[0], padding='same', activation=None)(input_img)
    block1 = activation()(block1)
    block1 = MaxPooling1D(pool_size=POOL_SIZE[0], strides=None, padding='same')(block1)
    block1 = BatchNormalization()(block1)
    block1 = Dropout(0.1)(block1)
    
    
    block2 = SeparableConv1D(N_KERNELS[1], KERNEL_SIZE[1], padding='same', activation=None)(block1)
    block2 = activation()(block2)
    block2 = MaxPooling1D(pool_size=POOL_SIZE[1], padding='same')(block2)
    block2 = BatchNormalization()(block2)
    block2 = Dropout(0.1)(block2)
    
    
    block3 = SeparableConv1D(N_KERNELS[2], KERNEL_SIZE[2], padding='same', activation=None)(block2)
    block3 = activation()(block3)
    block3 = MaxPooling1D(pool_size=POOL_SIZE[2], padding='same')(block3)
    block3 = BatchNormalization()(block3)
    block3 = Dropout(0.1)(block3)
    
    
    block4 = SeparableConv1D(N_KERNELS[3], KERNEL_SIZE[3], padding='same', activation=None)(block3)
    block4 = Activation('relu')(block4)
    block4 = MaxPooling1D(pool_size=POOL_SIZE[3], padding='same')(block4)
    block4 = BatchNormalization()(block4)
    block4 = Dropout(0.8)(block4)    
    
    block6 = Flatten()(block4)
    block6 = Dense(20, activation='sigmoid')(block6)
    block6 = BatchNormalization()(block6)
    block6 = Dropout(0.8)(block6)

    block7 = Dense(2, activation='softmax')(block6)

    return Model(input_img, block7)

# %%
# define input to the model:
x = Input(shape=(chan, leng, streams))

# make the model:
model = conv_net(leng)

# compile the model:
# sgd = optimizers.SGD(lr=0.01, decay=1e-4, momentum=0.95, nesterov=True)
# model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])
# model.compile(optimizer='rmsprop', loss=correlation_coefficient_loss)
model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(0.00001), metrics=["accuracy"])


# SEE INSIDE THE MODEL:
# conv_net().summary() #or
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 128, 60)           0
# _________________________________________________________________
# separable_conv1d_17 (Separab (None, 128, 3)            1743
# _________________________________________________________________
# elu_13 (ELU)                 (None, 128, 3)            0
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 64, 3)             0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 64, 3)             12
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 64, 3)             0
# _________________________________________________________________
# separable_conv1d_18 (Separab (None, 64, 40)            199
# _________________________________________________________________
# elu_14 (ELU)                 (None, 64, 40)            0
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 32, 40)            0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 32, 40)            160
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 32, 40)            0
# _________________________________________________________________
# separable_conv1d_19 (Separab (None, 32, 80)            3520
# _________________________________________________________________
# elu_15 (ELU)                 (None, 32, 80)            0
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 16, 80)            0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 16, 80)            320
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 16, 80)            0
# _________________________________________________________________
# separable_conv1d_20 (Separab (None, 16, 160)           13120
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 160)           0
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 8, 160)            0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 8, 160)            640
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 8, 160)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                25620
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 20)                80
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 45,456
# Trainable params: 44,850
# Non-trainable params: 606
# _________________________________________________________________

# %%
init_lr = 0.0005
lr_drop_by = 0.995
drop_every = 10

from keras.callbacks import TensorBoard, EarlyStopping, LearningRateScheduler, Callback, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=100, mode='min')

K.set_value(model.optimizer.lr, init_lr)

def step_decay(epoch, init_lr=init_lr, lr_drop=lr_drop_by, drop_every=drop_every):
    if epoch%drop_every==0:
        lrate = init_lr * (lr_drop_by ** np.floor((1+epoch)/drop_every))
    else:
        lrate = K.get_value(model.optimizer.lr)
    print('CHECK', epoch%drop_every)
    return lrate

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.lr = []
        self.batch_loss = []
        self.val_acc = []
 
    def on_epoch_end(self, epoch, batch, logs={}):
        lrate = step_decay(epoch)
        txt = K.get_value(model.optimizer.lr)
        self.lr.append(txt)
#         self.lr.append(lrate)
#         txt = K.eval(self.model.optimizer.lr)
        print('OPTIMIZERS lrate AT EPOCH END = ', txt, '\n\n')
    
    def on_epoch_begin(self, epoch, batch, logs={}):
        txt = K.get_value(model.optimizer.lr)
        print('OPTIMIZERS lrate AT EPOCH START = ', txt)

    def on_batch_end(self, batch, logs={}):
        self.batch_loss.append(logs.get('loss'))

lr_decay = LearningRateScheduler(schedule=step_decay)
loss_history = LossHistory()

checkpointer = ModelCheckpoint(filepath='/home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5',
                               verbose=1,
                               monitor='val_acc',
                               save_best_only=True)


train_history = model.fit(x_train, y_train,
                epochs=1000,
                batch_size=BATCH_SIZE,
                verbose=2,
                shuffle=True,
                validation_data=(x_test, y_test),
                callbacks=[checkpointer, early_stopping, lr_decay, loss_history])

# save the entire model and the weights after the training:
# model.save('/home/amplifier/home/NEW_DL/models/EEGnet_CNN_Dense_Binary_Classifier_TD_1D.h5')
# model.save_weights('/home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5')
# Out:
# Train on 337 samples, validate on 113 samples
# Epoch 1/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 3s - loss: 1.6772 - acc: 0.5326 - val_loss: 0.8062 - val_acc: 0.5133
#
# Epoch 00001: val_acc improved from -inf to 0.51327, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 2/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.7166 - acc: 0.5045 - val_loss: 0.8319 - val_acc: 0.5664
#
# Epoch 00002: val_acc improved from 0.51327 to 0.56637, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 3/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.5746 - acc: 0.5282 - val_loss: 0.7991 - val_acc: 0.5575
#
# Epoch 00003: val_acc did not improve from 0.56637
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 4/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.6214 - acc: 0.5163 - val_loss: 0.8182 - val_acc: 0.5664
#
# Epoch 00004: val_acc improved from 0.56637 to 0.56637, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 5/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.6364 - acc: 0.5312 - val_loss: 0.7999 - val_acc: 0.5664
#
# Epoch 00005: val_acc did not improve from 0.56637
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 6/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.8652 - acc: 0.4392 - val_loss: 0.7867 - val_acc: 0.5487
#
# Epoch 00006: val_acc did not improve from 0.56637
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 7/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.4511 - acc: 0.5490 - val_loss: 0.7810 - val_acc: 0.5575
#
# Epoch 00007: val_acc did not improve from 0.56637
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 8/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.5833 - acc: 0.4926 - val_loss: 0.8008 - val_acc: 0.5841
#
# Epoch 00008: val_acc improved from 0.56637 to 0.58407, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 9/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.4018 - acc: 0.5163 - val_loss: 0.7994 - val_acc: 0.5487
#
# Epoch 00009: val_acc did not improve from 0.58407
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 10/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0005
#  - 0s - loss: 1.4554 - acc: 0.5282 - val_loss: 0.7991 - val_acc: 0.5310
#
# Epoch 00010: val_acc did not improve from 0.58407
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0005
#
#
# Epoch 11/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.3912 - acc: 0.5252 - val_loss: 0.7991 - val_acc: 0.5398
#
# Epoch 00011: val_acc did not improve from 0.58407
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 12/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.3086 - acc: 0.4866 - val_loss: 0.7778 - val_acc: 0.5133
#
# Epoch 00012: val_acc did not improve from 0.58407
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 13/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.5010 - acc: 0.4777 - val_loss: 0.7520 - val_acc: 0.5487
#
# Epoch 00013: val_acc did not improve from 0.58407
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 14/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.2873 - acc: 0.5104 - val_loss: 0.7661 - val_acc: 0.5664
#
# Epoch 00014: val_acc did not improve from 0.58407
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 15/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.2256 - acc: 0.5015 - val_loss: 0.7786 - val_acc: 0.5487
#
# Epoch 00015: val_acc did not improve from 0.58407
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 16/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.2405 - acc: 0.5282 - val_loss: 0.7487 - val_acc: 0.5575
#
# Epoch 00016: val_acc did not improve from 0.58407
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 17/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.2957 - acc: 0.4807 - val_loss: 0.7188 - val_acc: 0.5221
#
# Epoch 00017: val_acc did not improve from 0.58407
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 18/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.1752 - acc: 0.5163 - val_loss: 0.7070 - val_acc: 0.5310
#
# Epoch 00018: val_acc did not improve from 0.58407
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 19/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.3383 - acc: 0.5193 - val_loss: 0.7276 - val_acc: 0.5398
#
# Epoch 00019: val_acc did not improve from 0.58407
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 20/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0004975
#  - 0s - loss: 1.0753 - acc: 0.5668 - val_loss: 0.7328 - val_acc: 0.5487
#
# Epoch 00020: val_acc did not improve from 0.58407
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0004975
#
#
# Epoch 21/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.2065 - acc: 0.5163 - val_loss: 0.7162 - val_acc: 0.5664
#
# Epoch 00021: val_acc did not improve from 0.58407
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 22/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.2950 - acc: 0.4926 - val_loss: 0.7109 - val_acc: 0.5575
#
# Epoch 00022: val_acc did not improve from 0.58407
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 23/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.2377 - acc: 0.4837 - val_loss: 0.7007 - val_acc: 0.5841
#
# Epoch 00023: val_acc did not improve from 0.58407
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 24/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.0703 - acc: 0.5252 - val_loss: 0.6919 - val_acc: 0.5664
#
# Epoch 00024: val_acc did not improve from 0.58407
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 25/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.0327 - acc: 0.5638 - val_loss: 0.6945 - val_acc: 0.5487
#
# Epoch 00025: val_acc did not improve from 0.58407
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 26/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 0.9466 - acc: 0.5638 - val_loss: 0.6879 - val_acc: 0.5575
#
# Epoch 00026: val_acc did not improve from 0.58407
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 27/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.1400 - acc: 0.5015 - val_loss: 0.6868 - val_acc: 0.5929
#
# Epoch 00027: val_acc improved from 0.58407 to 0.59292, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 28/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.0823 - acc: 0.5074 - val_loss: 0.6952 - val_acc: 0.5752
#
# Epoch 00028: val_acc did not improve from 0.59292
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 29/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 0.9568 - acc: 0.5193 - val_loss: 0.6958 - val_acc: 0.5310
#
# Epoch 00029: val_acc did not improve from 0.59292
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 30/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00049253745
#  - 0s - loss: 1.0016 - acc: 0.5371 - val_loss: 0.6914 - val_acc: 0.5575
#
# Epoch 00030: val_acc did not improve from 0.59292
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00049253745
#
#
# Epoch 31/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 1.0379 - acc: 0.5045 - val_loss: 0.6961 - val_acc: 0.5575
#
# Epoch 00031: val_acc did not improve from 0.59292
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 32/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.9841 - acc: 0.5401 - val_loss: 0.7084 - val_acc: 0.5310
#
# Epoch 00032: val_acc did not improve from 0.59292
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 33/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 1.0029 - acc: 0.5015 - val_loss: 0.7047 - val_acc: 0.5310
#
# Epoch 00033: val_acc did not improve from 0.59292
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 34/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.8510 - acc: 0.5519 - val_loss: 0.7075 - val_acc: 0.5575
#
# Epoch 00034: val_acc did not improve from 0.59292
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 35/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.9117 - acc: 0.5223 - val_loss: 0.7123 - val_acc: 0.5398
#
# Epoch 00035: val_acc did not improve from 0.59292
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 36/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.9890 - acc: 0.5193 - val_loss: 0.7139 - val_acc: 0.5133
#
# Epoch 00036: val_acc did not improve from 0.59292
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 37/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.8796 - acc: 0.5193 - val_loss: 0.7042 - val_acc: 0.5044
#
# Epoch 00037: val_acc did not improve from 0.59292
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 38/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.9785 - acc: 0.4955 - val_loss: 0.7059 - val_acc: 0.5133
#
# Epoch 00038: val_acc did not improve from 0.59292
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 39/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.8592 - acc: 0.5579 - val_loss: 0.7046 - val_acc: 0.5044
#
# Epoch 00039: val_acc did not improve from 0.59292
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 40/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00048518626
#  - 0s - loss: 0.8824 - acc: 0.5074 - val_loss: 0.7077 - val_acc: 0.4956
#
# Epoch 00040: val_acc did not improve from 0.59292
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00048518626
#
#
# Epoch 41/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8554 - acc: 0.5312 - val_loss: 0.7036 - val_acc: 0.4867
#
# Epoch 00041: val_acc did not improve from 0.59292
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 42/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8401 - acc: 0.5579 - val_loss: 0.7000 - val_acc: 0.5133
#
# Epoch 00042: val_acc did not improve from 0.59292
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 43/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8126 - acc: 0.5579 - val_loss: 0.7008 - val_acc: 0.4956
#
# Epoch 00043: val_acc did not improve from 0.59292
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 44/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8443 - acc: 0.5341 - val_loss: 0.6945 - val_acc: 0.5310
#
# Epoch 00044: val_acc did not improve from 0.59292
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 45/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8423 - acc: 0.5401 - val_loss: 0.6991 - val_acc: 0.4956
#
# Epoch 00045: val_acc did not improve from 0.59292
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 46/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.7620 - acc: 0.5579 - val_loss: 0.6989 - val_acc: 0.5133
#
# Epoch 00046: val_acc did not improve from 0.59292
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 47/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8512 - acc: 0.5074 - val_loss: 0.6929 - val_acc: 0.5133
#
# Epoch 00047: val_acc did not improve from 0.59292
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 48/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.7909 - acc: 0.5608 - val_loss: 0.6905 - val_acc: 0.5221
#
# Epoch 00048: val_acc did not improve from 0.59292
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 49/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8605 - acc: 0.4985 - val_loss: 0.6794 - val_acc: 0.5575
#
# Epoch 00049: val_acc did not improve from 0.59292
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 50/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00047555508
#  - 0s - loss: 0.8037 - acc: 0.5579 - val_loss: 0.6765 - val_acc: 0.5310
#
# Epoch 00050: val_acc did not improve from 0.59292
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00047555508
#
#
# Epoch 51/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.8164 - acc: 0.5074 - val_loss: 0.6736 - val_acc: 0.5310
#
# Epoch 00051: val_acc did not improve from 0.59292
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 52/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.8254 - acc: 0.5104 - val_loss: 0.6750 - val_acc: 0.5487
#
# Epoch 00052: val_acc did not improve from 0.59292
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 53/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7282 - acc: 0.5786 - val_loss: 0.6737 - val_acc: 0.5664
#
# Epoch 00053: val_acc did not improve from 0.59292
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 54/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7800 - acc: 0.5252 - val_loss: 0.6771 - val_acc: 0.5752
#
# Epoch 00054: val_acc did not improve from 0.59292
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 55/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7506 - acc: 0.5697 - val_loss: 0.6758 - val_acc: 0.5575
#
# Epoch 00055: val_acc did not improve from 0.59292
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 56/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7908 - acc: 0.5223 - val_loss: 0.6800 - val_acc: 0.5752
#
# Epoch 00056: val_acc did not improve from 0.59292
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 57/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7369 - acc: 0.5727 - val_loss: 0.6780 - val_acc: 0.5752
#
# Epoch 00057: val_acc did not improve from 0.59292
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 58/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7538 - acc: 0.5460 - val_loss: 0.6795 - val_acc: 0.5752
#
# Epoch 00058: val_acc did not improve from 0.59292
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 59/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.6864 - acc: 0.5964 - val_loss: 0.6762 - val_acc: 0.5752
#
# Epoch 00059: val_acc did not improve from 0.59292
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 60/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0004637845
#  - 0s - loss: 0.7481 - acc: 0.5371 - val_loss: 0.6752 - val_acc: 0.5752
#
# Epoch 00060: val_acc did not improve from 0.59292
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0004637845
#
#
# Epoch 61/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7569 - acc: 0.5252 - val_loss: 0.6752 - val_acc: 0.5929
#
# Epoch 00061: val_acc improved from 0.59292 to 0.59292, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 62/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7878 - acc: 0.4777 - val_loss: 0.6747 - val_acc: 0.5841
#
# Epoch 00062: val_acc did not improve from 0.59292
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 63/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7480 - acc: 0.5490 - val_loss: 0.6710 - val_acc: 0.5664
#
# Epoch 00063: val_acc did not improve from 0.59292
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 64/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7071 - acc: 0.5964 - val_loss: 0.6697 - val_acc: 0.5752
#
# Epoch 00064: val_acc did not improve from 0.59292
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 65/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.6918 - acc: 0.5608 - val_loss: 0.6703 - val_acc: 0.5664
#
# Epoch 00065: val_acc did not improve from 0.59292
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 66/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7306 - acc: 0.5519 - val_loss: 0.6644 - val_acc: 0.5752
#
# Epoch 00066: val_acc did not improve from 0.59292
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 67/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7342 - acc: 0.5193 - val_loss: 0.6646 - val_acc: 0.5929
#
# Epoch 00067: val_acc did not improve from 0.59292
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 68/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.7041 - acc: 0.5816 - val_loss: 0.6601 - val_acc: 0.6018
#
# Epoch 00068: val_acc improved from 0.59292 to 0.60177, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 69/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.6829 - acc: 0.6380 - val_loss: 0.6582 - val_acc: 0.6106
#
# Epoch 00069: val_acc improved from 0.60177 to 0.61062, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 70/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00045004374
#  - 0s - loss: 0.6985 - acc: 0.5668 - val_loss: 0.6580 - val_acc: 0.6018
#
# Epoch 00070: val_acc did not improve from 0.61062
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00045004374
#
#
# Epoch 71/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.7100 - acc: 0.5638 - val_loss: 0.6568 - val_acc: 0.6018
#
# Epoch 00071: val_acc did not improve from 0.61062
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 72/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6942 - acc: 0.5519 - val_loss: 0.6585 - val_acc: 0.6018
#
# Epoch 00072: val_acc did not improve from 0.61062
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 73/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6971 - acc: 0.5460 - val_loss: 0.6578 - val_acc: 0.6195
#
# Epoch 00073: val_acc improved from 0.61062 to 0.61947, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 74/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.7042 - acc: 0.5579 - val_loss: 0.6556 - val_acc: 0.6106
#
# Epoch 00074: val_acc did not improve from 0.61947
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 75/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6896 - acc: 0.5608 - val_loss: 0.6515 - val_acc: 0.6018
#
# Epoch 00075: val_acc did not improve from 0.61947
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 76/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.7097 - acc: 0.5460 - val_loss: 0.6527 - val_acc: 0.6195
#
# Epoch 00076: val_acc did not improve from 0.61947
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 77/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6805 - acc: 0.5846 - val_loss: 0.6526 - val_acc: 0.6195
#
# Epoch 00077: val_acc did not improve from 0.61947
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 78/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6927 - acc: 0.5816 - val_loss: 0.6542 - val_acc: 0.6195
#
# Epoch 00078: val_acc did not improve from 0.61947
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 79/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6781 - acc: 0.5727 - val_loss: 0.6538 - val_acc: 0.6283
#
# Epoch 00079: val_acc improved from 0.61947 to 0.62832, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 80/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0004345265
#  - 0s - loss: 0.6773 - acc: 0.5816 - val_loss: 0.6545 - val_acc: 0.6195
#
# Epoch 00080: val_acc did not improve from 0.62832
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0004345265
#
#
# Epoch 81/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.7013 - acc: 0.5460 - val_loss: 0.6535 - val_acc: 0.6195
#
# Epoch 00081: val_acc did not improve from 0.62832
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 82/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.7061 - acc: 0.5312 - val_loss: 0.6522 - val_acc: 0.6283
#
# Epoch 00082: val_acc did not improve from 0.62832
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 83/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6755 - acc: 0.5697 - val_loss: 0.6527 - val_acc: 0.6283
#
# Epoch 00083: val_acc improved from 0.62832 to 0.62832, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 84/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6619 - acc: 0.6172 - val_loss: 0.6505 - val_acc: 0.6460
#
# Epoch 00084: val_acc improved from 0.62832 to 0.64602, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 85/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6923 - acc: 0.5134 - val_loss: 0.6507 - val_acc: 0.6372
#
# Epoch 00085: val_acc did not improve from 0.64602
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 86/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6686 - acc: 0.5727 - val_loss: 0.6532 - val_acc: 0.6106
#
# Epoch 00086: val_acc did not improve from 0.64602
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 87/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6805 - acc: 0.5994 - val_loss: 0.6556 - val_acc: 0.6106
#
# Epoch 00087: val_acc did not improve from 0.64602
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 88/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6971 - acc: 0.5371 - val_loss: 0.6574 - val_acc: 0.5929
#
# Epoch 00088: val_acc did not improve from 0.64602
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 89/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6643 - acc: 0.6172 - val_loss: 0.6589 - val_acc: 0.5929
#
# Epoch 00089: val_acc did not improve from 0.64602
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 90/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0004174466
#  - 0s - loss: 0.6764 - acc: 0.5608 - val_loss: 0.6575 - val_acc: 0.6195
#
# Epoch 00090: val_acc did not improve from 0.64602
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0004174466
#
#
# Epoch 91/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6888 - acc: 0.5697 - val_loss: 0.6553 - val_acc: 0.6283
#
# Epoch 00091: val_acc did not improve from 0.64602
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 92/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6943 - acc: 0.5549 - val_loss: 0.6528 - val_acc: 0.6195
#
# Epoch 00092: val_acc did not improve from 0.64602
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 93/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6867 - acc: 0.5816 - val_loss: 0.6512 - val_acc: 0.6195
#
# Epoch 00093: val_acc did not improve from 0.64602
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 94/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6512 - acc: 0.6172 - val_loss: 0.6503 - val_acc: 0.6283
#
# Epoch 00094: val_acc did not improve from 0.64602
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 95/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6533 - acc: 0.6202 - val_loss: 0.6484 - val_acc: 0.6372
#
# Epoch 00095: val_acc did not improve from 0.64602
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 96/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6694 - acc: 0.5697 - val_loss: 0.6435 - val_acc: 0.6460
#
# Epoch 00096: val_acc improved from 0.64602 to 0.64602, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 97/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6839 - acc: 0.5875 - val_loss: 0.6418 - val_acc: 0.6726
#
# Epoch 00097: val_acc improved from 0.64602 to 0.67257, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 98/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6575 - acc: 0.6024 - val_loss: 0.6387 - val_acc: 0.6726
#
# Epoch 00098: val_acc did not improve from 0.67257
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 99/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6632 - acc: 0.6409 - val_loss: 0.6385 - val_acc: 0.6814
#
# Epoch 00099: val_acc improved from 0.67257 to 0.68142, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 100/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00039903287
#  - 0s - loss: 0.6673 - acc: 0.5727 - val_loss: 0.6373 - val_acc: 0.6814
#
# Epoch 00100: val_acc did not improve from 0.68142
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00039903287
#
#
# Epoch 101/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6847 - acc: 0.5668 - val_loss: 0.6400 - val_acc: 0.6726
#
# Epoch 00101: val_acc did not improve from 0.68142
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 102/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6886 - acc: 0.5668 - val_loss: 0.6443 - val_acc: 0.6460
#
# Epoch 00102: val_acc did not improve from 0.68142
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 103/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6615 - acc: 0.6202 - val_loss: 0.6419 - val_acc: 0.6549
#
# Epoch 00103: val_acc did not improve from 0.68142
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 104/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6519 - acc: 0.6350 - val_loss: 0.6410 - val_acc: 0.6549
#
# Epoch 00104: val_acc did not improve from 0.68142
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 105/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6705 - acc: 0.5786 - val_loss: 0.6412 - val_acc: 0.6549
#
# Epoch 00105: val_acc did not improve from 0.68142
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 106/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6666 - acc: 0.6083 - val_loss: 0.6418 - val_acc: 0.6549
#
# Epoch 00106: val_acc did not improve from 0.68142
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 107/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6555 - acc: 0.6350 - val_loss: 0.6440 - val_acc: 0.6372
#
# Epoch 00107: val_acc did not improve from 0.68142
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 108/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6519 - acc: 0.6231 - val_loss: 0.6346 - val_acc: 0.6814
#
# Epoch 00108: val_acc improved from 0.68142 to 0.68142, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 109/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6704 - acc: 0.5964 - val_loss: 0.6309 - val_acc: 0.6814
#
# Epoch 00109: val_acc did not improve from 0.68142
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 110/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0003795242
#  - 0s - loss: 0.6786 - acc: 0.5757 - val_loss: 0.6312 - val_acc: 0.6903
#
# Epoch 00110: val_acc improved from 0.68142 to 0.69027, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0003795242
#
#
# Epoch 111/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6342 - acc: 0.6617 - val_loss: 0.6331 - val_acc: 0.6637
#
# Epoch 00111: val_acc did not improve from 0.69027
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 112/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6427 - acc: 0.6409 - val_loss: 0.6332 - val_acc: 0.6549
#
# Epoch 00112: val_acc did not improve from 0.69027
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 113/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6674 - acc: 0.5964 - val_loss: 0.6333 - val_acc: 0.6549
#
# Epoch 00113: val_acc did not improve from 0.69027
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 114/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6506 - acc: 0.6083 - val_loss: 0.6292 - val_acc: 0.6726
#
# Epoch 00114: val_acc did not improve from 0.69027
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 115/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6446 - acc: 0.6053 - val_loss: 0.6393 - val_acc: 0.6283
#
# Epoch 00115: val_acc did not improve from 0.69027
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 116/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6368 - acc: 0.6350 - val_loss: 0.6434 - val_acc: 0.6195
#
# Epoch 00116: val_acc did not improve from 0.69027
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 117/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6454 - acc: 0.6350 - val_loss: 0.6444 - val_acc: 0.6283
#
# Epoch 00117: val_acc did not improve from 0.69027
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 118/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6345 - acc: 0.6439 - val_loss: 0.6400 - val_acc: 0.6372
#
# Epoch 00118: val_acc did not improve from 0.69027
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 119/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6337 - acc: 0.6766 - val_loss: 0.6327 - val_acc: 0.6372
#
# Epoch 00119: val_acc did not improve from 0.69027
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 120/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00035916446
#  - 0s - loss: 0.6516 - acc: 0.6380 - val_loss: 0.6280 - val_acc: 0.6549
#
# Epoch 00120: val_acc did not improve from 0.69027
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00035916446
#
#
# Epoch 121/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6294 - acc: 0.6320 - val_loss: 0.6231 - val_acc: 0.6549
#
# Epoch 00121: val_acc did not improve from 0.69027
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 122/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6468 - acc: 0.6202 - val_loss: 0.6191 - val_acc: 0.6460
#
# Epoch 00122: val_acc did not improve from 0.69027
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 123/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6190 - acc: 0.6736 - val_loss: 0.6214 - val_acc: 0.6283
#
# Epoch 00123: val_acc did not improve from 0.69027
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 124/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6390 - acc: 0.6142 - val_loss: 0.6194 - val_acc: 0.6372
#
# Epoch 00124: val_acc did not improve from 0.69027
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 125/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6221 - acc: 0.6409 - val_loss: 0.6210 - val_acc: 0.6372
#
# Epoch 00125: val_acc did not improve from 0.69027
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 126/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6198 - acc: 0.6469 - val_loss: 0.6250 - val_acc: 0.6283
#
# Epoch 00126: val_acc did not improve from 0.69027
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 127/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6252 - acc: 0.6439 - val_loss: 0.6308 - val_acc: 0.6283
#
# Epoch 00127: val_acc did not improve from 0.69027
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 128/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6211 - acc: 0.6380 - val_loss: 0.6316 - val_acc: 0.6372
#
# Epoch 00128: val_acc did not improve from 0.69027
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 129/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.5953 - acc: 0.7033 - val_loss: 0.6191 - val_acc: 0.6460
#
# Epoch 00129: val_acc did not improve from 0.69027
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 130/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00033819745
#  - 0s - loss: 0.6199 - acc: 0.6706 - val_loss: 0.6247 - val_acc: 0.6460
#
# Epoch 00130: val_acc did not improve from 0.69027
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00033819745
#
#
# Epoch 131/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.5979 - acc: 0.6944 - val_loss: 0.6219 - val_acc: 0.6460
#
# Epoch 00131: val_acc did not improve from 0.69027
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 132/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.6274 - acc: 0.6706 - val_loss: 0.6259 - val_acc: 0.6283
#
# Epoch 00132: val_acc did not improve from 0.69027
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 133/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.6186 - acc: 0.6647 - val_loss: 0.6308 - val_acc: 0.6372
#
# Epoch 00133: val_acc did not improve from 0.69027
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 134/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.5680 - acc: 0.7033 - val_loss: 0.6145 - val_acc: 0.6283
#
# Epoch 00134: val_acc did not improve from 0.69027
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 135/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.5863 - acc: 0.7003 - val_loss: 0.6167 - val_acc: 0.6283
#
# Epoch 00135: val_acc did not improve from 0.69027
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 136/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.6043 - acc: 0.6795 - val_loss: 0.6207 - val_acc: 0.6283
#
# Epoch 00136: val_acc did not improve from 0.69027
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 137/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.6016 - acc: 0.6973 - val_loss: 0.6287 - val_acc: 0.6283
#
# Epoch 00137: val_acc did not improve from 0.69027
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 138/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.5903 - acc: 0.6914 - val_loss: 0.6220 - val_acc: 0.6372
#
# Epoch 00138: val_acc did not improve from 0.69027
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 139/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.5703 - acc: 0.7062 - val_loss: 0.6164 - val_acc: 0.6460
#
# Epoch 00139: val_acc did not improve from 0.69027
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 140/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00031686216
#  - 0s - loss: 0.5608 - acc: 0.6825 - val_loss: 0.6338 - val_acc: 0.6195
#
# Epoch 00140: val_acc did not improve from 0.69027
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00031686216
#
#
# Epoch 141/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5611 - acc: 0.7240 - val_loss: 0.6455 - val_acc: 0.6195
#
# Epoch 00141: val_acc did not improve from 0.69027
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 142/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5997 - acc: 0.6766 - val_loss: 0.6636 - val_acc: 0.6018
#
# Epoch 00142: val_acc did not improve from 0.69027
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 143/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5952 - acc: 0.7240 - val_loss: 0.6459 - val_acc: 0.6106
#
# Epoch 00143: val_acc did not improve from 0.69027
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 144/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5652 - acc: 0.7389 - val_loss: 0.6527 - val_acc: 0.6195
#
# Epoch 00144: val_acc did not improve from 0.69027
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 145/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5711 - acc: 0.7003 - val_loss: 0.6520 - val_acc: 0.6195
#
# Epoch 00145: val_acc did not improve from 0.69027
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 146/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5215 - acc: 0.7656 - val_loss: 0.6485 - val_acc: 0.6283
#
# Epoch 00146: val_acc did not improve from 0.69027
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 147/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5652 - acc: 0.7270 - val_loss: 0.6254 - val_acc: 0.6195
#
# Epoch 00147: val_acc did not improve from 0.69027
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 148/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5907 - acc: 0.6677 - val_loss: 0.6662 - val_acc: 0.6283
#
# Epoch 00148: val_acc did not improve from 0.69027
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 149/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5134 - acc: 0.7715 - val_loss: 0.6985 - val_acc: 0.6283
#
# Epoch 00149: val_acc did not improve from 0.69027
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 150/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00029538845
#  - 0s - loss: 0.5206 - acc: 0.7567 - val_loss: 0.6688 - val_acc: 0.6195
#
# Epoch 00150: val_acc did not improve from 0.69027
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00029538845
#
#
# Epoch 151/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5030 - acc: 0.7596 - val_loss: 0.6941 - val_acc: 0.6283
#
# Epoch 00151: val_acc did not improve from 0.69027
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 152/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5256 - acc: 0.7567 - val_loss: 0.7471 - val_acc: 0.6018
#
# Epoch 00152: val_acc did not improve from 0.69027
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 153/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5529 - acc: 0.7626 - val_loss: 0.7983 - val_acc: 0.5752
#
# Epoch 00153: val_acc did not improve from 0.69027
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 154/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5382 - acc: 0.7478 - val_loss: 0.7445 - val_acc: 0.6106
#
# Epoch 00154: val_acc did not improve from 0.69027
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 155/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.4918 - acc: 0.7804 - val_loss: 0.7063 - val_acc: 0.6195
#
# Epoch 00155: val_acc did not improve from 0.69027
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 156/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5250 - acc: 0.7300 - val_loss: 0.7422 - val_acc: 0.6106
#
# Epoch 00156: val_acc did not improve from 0.69027
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 157/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5409 - acc: 0.7389 - val_loss: 0.7025 - val_acc: 0.6195
#
# Epoch 00157: val_acc did not improve from 0.69027
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 158/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5313 - acc: 0.7567 - val_loss: 0.7065 - val_acc: 0.6283
#
# Epoch 00158: val_acc did not improve from 0.69027
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 159/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.4930 - acc: 0.7745 - val_loss: 0.7140 - val_acc: 0.6283
#
# Epoch 00159: val_acc did not improve from 0.69027
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 160/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00027399315
#  - 0s - loss: 0.5032 - acc: 0.7685 - val_loss: 0.7122 - val_acc: 0.6372
#
# Epoch 00160: val_acc did not improve from 0.69027
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00027399315
#
#
# Epoch 161/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4975 - acc: 0.7953 - val_loss: 0.6063 - val_acc: 0.6637
#
# Epoch 00161: val_acc did not improve from 0.69027
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 162/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4928 - acc: 0.7715 - val_loss: 0.5834 - val_acc: 0.6726
#
# Epoch 00162: val_acc did not improve from 0.69027
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 163/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.5181 - acc: 0.7685 - val_loss: 0.6045 - val_acc: 0.6726
#
# Epoch 00163: val_acc did not improve from 0.69027
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 164/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.5177 - acc: 0.7389 - val_loss: 0.6517 - val_acc: 0.6460
#
# Epoch 00164: val_acc did not improve from 0.69027
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 165/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4951 - acc: 0.7774 - val_loss: 0.6019 - val_acc: 0.6991
#
# Epoch 00165: val_acc improved from 0.69027 to 0.69912, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 166/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4472 - acc: 0.8101 - val_loss: 0.5536 - val_acc: 0.7345
#
# Epoch 00166: val_acc improved from 0.69912 to 0.73451, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 167/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.5258 - acc: 0.7418 - val_loss: 0.5446 - val_acc: 0.7434
#
# Epoch 00167: val_acc improved from 0.73451 to 0.74336, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 168/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4533 - acc: 0.8012 - val_loss: 0.5993 - val_acc: 0.7080
#
# Epoch 00168: val_acc did not improve from 0.74336
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 169/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4651 - acc: 0.7982 - val_loss: 0.6038 - val_acc: 0.6903
#
# Epoch 00169: val_acc did not improve from 0.74336
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 170/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.0002528768
#  - 0s - loss: 0.4540 - acc: 0.7774 - val_loss: 0.6482 - val_acc: 0.6726
#
# Epoch 00170: val_acc did not improve from 0.74336
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.0002528768
#
#
# Epoch 171/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4865 - acc: 0.7834 - val_loss: 0.6426 - val_acc: 0.6549
#
# Epoch 00171: val_acc did not improve from 0.74336
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 172/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4421 - acc: 0.8368 - val_loss: 0.6365 - val_acc: 0.6814
#
# Epoch 00172: val_acc did not improve from 0.74336
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 173/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4731 - acc: 0.8012 - val_loss: 0.5697 - val_acc: 0.7345
#
# Epoch 00173: val_acc did not improve from 0.74336
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 174/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4663 - acc: 0.7834 - val_loss: 0.4931 - val_acc: 0.7788
#
# Epoch 00174: val_acc improved from 0.74336 to 0.77876, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 175/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4281 - acc: 0.8101 - val_loss: 0.4930 - val_acc: 0.8053
#
# Epoch 00175: val_acc improved from 0.77876 to 0.80531, saving model to /home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 176/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4366 - acc: 0.8220 - val_loss: 0.5189 - val_acc: 0.7876
#
# Epoch 00176: val_acc did not improve from 0.80531
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 177/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4334 - acc: 0.8220 - val_loss: 0.5806 - val_acc: 0.7345
#
# Epoch 00177: val_acc did not improve from 0.80531
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 178/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4571 - acc: 0.8101 - val_loss: 0.5714 - val_acc: 0.7434
#
# Epoch 00178: val_acc did not improve from 0.80531
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 179/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4236 - acc: 0.8457 - val_loss: 0.5621 - val_acc: 0.7611
#
# Epoch 00179: val_acc did not improve from 0.80531
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 180/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  0.00023222093
#  - 0s - loss: 0.4971 - acc: 0.7715 - val_loss: 0.6857 - val_acc: 0.6637
#
# Epoch 00180: val_acc did not improve from 0.80531
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  0.00023222093
#
#
# Epoch 181/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  0.00021218605
#  - 0s - loss: 0.4416 - acc: 0.8101 - val_loss: 0.7079 - val_acc: 0.6637
#
# Epoch 00181: val_acc did not improve from 0.80531
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  0.00021218605
#
#
# Epoch 182/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  0.00021218605
#  - 0s - loss: 0.4347 - acc: 0.8042 - val_loss: 0.6304 - val_acc: 0.6991
#
# Epoch 00182: val_acc did not improve from 0.80531
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  0.00021218605
#
#
# Epoch 183/1000
# CHECK 2
# ...
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  8.6073866e-05
#
#
# Epoch 267/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  8.6073866e-05
#  - 0s - loss: 0.2960 - acc: 0.8902 - val_loss: 0.4755 - val_acc: 0.8407
#
# Epoch 00267: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  8.6073866e-05
#
#
# Epoch 268/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  8.6073866e-05
#  - 0s - loss: 0.3344 - acc: 0.8487 - val_loss: 0.4938 - val_acc: 0.8142
#
# Epoch 00268: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  8.6073866e-05
#
#
# Epoch 269/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  8.6073866e-05
#  - 0s - loss: 0.3276 - acc: 0.8932 - val_loss: 0.5168 - val_acc: 0.8053
#
# Epoch 00269: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  8.6073866e-05
#
#
# Epoch 270/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  8.6073866e-05
#  - 0s - loss: 0.2962 - acc: 0.8991 - val_loss: 0.5117 - val_acc: 0.8230
#
# Epoch 00270: val_acc did not improve from 0.84956
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  8.6073866e-05
#
#
# Epoch 271/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.2934 - acc: 0.8961 - val_loss: 0.5093 - val_acc: 0.8230
#
# Epoch 00271: val_acc did not improve from 0.84956
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 272/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.3431 - acc: 0.8635 - val_loss: 0.4988 - val_acc: 0.8230
#
# Epoch 00272: val_acc did not improve from 0.84956
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 273/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.2681 - acc: 0.9110 - val_loss: 0.5057 - val_acc: 0.8230
#
# Epoch 00273: val_acc did not improve from 0.84956
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 274/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.3623 - acc: 0.8605 - val_loss: 0.5128 - val_acc: 0.8319
#
# Epoch 00274: val_acc did not improve from 0.84956
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 275/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.3363 - acc: 0.8457 - val_loss: 0.5120 - val_acc: 0.8319
#
# Epoch 00275: val_acc did not improve from 0.84956
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 276/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.2595 - acc: 0.9169 - val_loss: 0.5126 - val_acc: 0.8319
#
# Epoch 00276: val_acc did not improve from 0.84956
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 277/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.2461 - acc: 0.9139 - val_loss: 0.5075 - val_acc: 0.8319
#
# Epoch 00277: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 278/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.2987 - acc: 0.9139 - val_loss: 0.4942 - val_acc: 0.8319
#
# Epoch 00278: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 279/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.3677 - acc: 0.8576 - val_loss: 0.4782 - val_acc: 0.8319
#
# Epoch 00279: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 280/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  7.517864e-05
#  - 0s - loss: 0.2593 - acc: 0.9050 - val_loss: 0.4891 - val_acc: 0.8407
#
# Epoch 00280: val_acc did not improve from 0.84956
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  7.517864e-05
#
#
# Epoch 281/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2347 - acc: 0.9199 - val_loss: 0.4955 - val_acc: 0.8319
#
# Epoch 00281: val_acc did not improve from 0.84956
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 282/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2892 - acc: 0.8813 - val_loss: 0.4804 - val_acc: 0.8407
#
# Epoch 00282: val_acc did not improve from 0.84956
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 283/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2752 - acc: 0.8783 - val_loss: 0.4882 - val_acc: 0.8319
#
# Epoch 00283: val_acc did not improve from 0.84956
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 284/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.3419 - acc: 0.8783 - val_loss: 0.4955 - val_acc: 0.8407
#
# Epoch 00284: val_acc did not improve from 0.84956
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 285/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2789 - acc: 0.9110 - val_loss: 0.4912 - val_acc: 0.8230
#
# Epoch 00285: val_acc did not improve from 0.84956
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 286/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2553 - acc: 0.9080 - val_loss: 0.4978 - val_acc: 0.8319
#
# Epoch 00286: val_acc did not improve from 0.84956
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 287/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2415 - acc: 0.9228 - val_loss: 0.4994 - val_acc: 0.8230
#
# Epoch 00287: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 288/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2642 - acc: 0.8961 - val_loss: 0.5012 - val_acc: 0.8230
#
# Epoch 00288: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 289/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.3298 - acc: 0.8754 - val_loss: 0.5018 - val_acc: 0.8319
#
# Epoch 00289: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 290/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  6.533422e-05
#  - 0s - loss: 0.2878 - acc: 0.8902 - val_loss: 0.5012 - val_acc: 0.8319
#
# Epoch 00290: val_acc did not improve from 0.84956
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  6.533422e-05
#
#
# Epoch 291/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2412 - acc: 0.9228 - val_loss: 0.5027 - val_acc: 0.8230
#
# Epoch 00291: val_acc did not improve from 0.84956
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 292/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2901 - acc: 0.8932 - val_loss: 0.5136 - val_acc: 0.8142
#
# Epoch 00292: val_acc did not improve from 0.84956
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 293/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2419 - acc: 0.9110 - val_loss: 0.5125 - val_acc: 0.8230
#
# Epoch 00293: val_acc did not improve from 0.84956
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 294/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2931 - acc: 0.8961 - val_loss: 0.5175 - val_acc: 0.8230
#
# Epoch 00294: val_acc did not improve from 0.84956
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 295/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2979 - acc: 0.8754 - val_loss: 0.5305 - val_acc: 0.8142
#
# Epoch 00295: val_acc did not improve from 0.84956
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 296/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2783 - acc: 0.9110 - val_loss: 0.5245 - val_acc: 0.8142
#
# Epoch 00296: val_acc did not improve from 0.84956
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 297/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2419 - acc: 0.9258 - val_loss: 0.5199 - val_acc: 0.8142
#
# Epoch 00297: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 298/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2463 - acc: 0.9139 - val_loss: 0.5203 - val_acc: 0.8142
#
# Epoch 00298: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 299/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2707 - acc: 0.9080 - val_loss: 0.5092 - val_acc: 0.8319
#
# Epoch 00299: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 300/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  5.6495006e-05
#  - 0s - loss: 0.2952 - acc: 0.8991 - val_loss: 0.5021 - val_acc: 0.8319
#
# Epoch 00300: val_acc did not improve from 0.84956
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  5.6495006e-05
#
#
# Epoch 301/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.2690 - acc: 0.8961 - val_loss: 0.5020 - val_acc: 0.8230
#
# Epoch 00301: val_acc did not improve from 0.84956
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 302/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.3346 - acc: 0.8872 - val_loss: 0.4988 - val_acc: 0.8496
#
# Epoch 00302: val_acc did not improve from 0.84956
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 303/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.3345 - acc: 0.8932 - val_loss: 0.4851 - val_acc: 0.8407
#
# Epoch 00303: val_acc did not improve from 0.84956
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 304/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.2465 - acc: 0.8932 - val_loss: 0.4797 - val_acc: 0.8319
#
# Epoch 00304: val_acc did not improve from 0.84956
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 305/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.2564 - acc: 0.8991 - val_loss: 0.4808 - val_acc: 0.8142
#
# Epoch 00305: val_acc did not improve from 0.84956
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 306/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.3151 - acc: 0.8813 - val_loss: 0.4941 - val_acc: 0.8230
#
# Epoch 00306: val_acc did not improve from 0.84956
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 307/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.2331 - acc: 0.9169 - val_loss: 0.4982 - val_acc: 0.8319
#
# Epoch 00307: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 308/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.2303 - acc: 0.9199 - val_loss: 0.4927 - val_acc: 0.8319
#
# Epoch 00308: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 309/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.3174 - acc: 0.8694 - val_loss: 0.4935 - val_acc: 0.8230
#
# Epoch 00309: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 310/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  4.860741e-05
#  - 0s - loss: 0.3094 - acc: 0.8872 - val_loss: 0.4926 - val_acc: 0.8319
#
# Epoch 00310: val_acc did not improve from 0.84956
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  4.860741e-05
#
#
# Epoch 311/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2898 - acc: 0.8754 - val_loss: 0.4919 - val_acc: 0.8319
#
# Epoch 00311: val_acc did not improve from 0.84956
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 312/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2706 - acc: 0.8961 - val_loss: 0.4875 - val_acc: 0.8230
#
# Epoch 00312: val_acc did not improve from 0.84956
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 313/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2602 - acc: 0.9050 - val_loss: 0.4812 - val_acc: 0.8142
#
# Epoch 00313: val_acc did not improve from 0.84956
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 314/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2457 - acc: 0.9228 - val_loss: 0.4805 - val_acc: 0.8142
#
# Epoch 00314: val_acc did not improve from 0.84956
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 315/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2818 - acc: 0.9228 - val_loss: 0.4888 - val_acc: 0.8142
#
# Epoch 00315: val_acc did not improve from 0.84956
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 316/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.3496 - acc: 0.8783 - val_loss: 0.4962 - val_acc: 0.8142
#
# Epoch 00316: val_acc did not improve from 0.84956
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 317/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2508 - acc: 0.9021 - val_loss: 0.4899 - val_acc: 0.8142
#
# Epoch 00317: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 318/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2824 - acc: 0.8991 - val_loss: 0.4837 - val_acc: 0.8142
#
# Epoch 00318: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 319/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2664 - acc: 0.9199 - val_loss: 0.4843 - val_acc: 0.8142
#
# Epoch 00319: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 320/1000
# CHECK 9
# OPTIMIZERS lrate AT EPOCH START =  4.161194e-05
#  - 0s - loss: 0.2225 - acc: 0.9318 - val_loss: 0.4856 - val_acc: 0.8142
#
# Epoch 00320: val_acc did not improve from 0.84956
# CHECK 9
# OPTIMIZERS lrate AT EPOCH END =  4.161194e-05
#
#
# Epoch 321/1000
# CHECK 0
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2517 - acc: 0.9288 - val_loss: 0.4926 - val_acc: 0.8053
#
# Epoch 00321: val_acc did not improve from 0.84956
# CHECK 0
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 322/1000
# CHECK 1
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2707 - acc: 0.8932 - val_loss: 0.5000 - val_acc: 0.8230
#
# Epoch 00322: val_acc did not improve from 0.84956
# CHECK 1
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 323/1000
# CHECK 2
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2320 - acc: 0.9199 - val_loss: 0.5027 - val_acc: 0.8230
#
# Epoch 00323: val_acc did not improve from 0.84956
# CHECK 2
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 324/1000
# CHECK 3
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2483 - acc: 0.9139 - val_loss: 0.5064 - val_acc: 0.8142
#
# Epoch 00324: val_acc did not improve from 0.84956
# CHECK 3
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 325/1000
# CHECK 4
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2465 - acc: 0.9139 - val_loss: 0.5092 - val_acc: 0.8053
#
# Epoch 00325: val_acc did not improve from 0.84956
# CHECK 4
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 326/1000
# CHECK 5
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2379 - acc: 0.9228 - val_loss: 0.5162 - val_acc: 0.8142
#
# Epoch 00326: val_acc did not improve from 0.84956
# CHECK 5
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 327/1000
# CHECK 6
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2986 - acc: 0.8961 - val_loss: 0.5198 - val_acc: 0.8142
#
# Epoch 00327: val_acc did not improve from 0.84956
# CHECK 6
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 328/1000
# CHECK 7
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2298 - acc: 0.9110 - val_loss: 0.5222 - val_acc: 0.8053
#
# Epoch 00328: val_acc did not improve from 0.84956
# CHECK 7
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05
#
#
# Epoch 329/1000
# CHECK 8
# OPTIMIZERS lrate AT EPOCH START =  3.544513e-05
#  - 0s - loss: 0.2805 - acc: 0.8902 - val_loss: 0.5234 - val_acc: 0.8053
#
# Epoch 00329: val_acc did not improve from 0.84956
# CHECK 8
# OPTIMIZERS lrate AT EPOCH END =  3.544513e-05

# %%
model.load_weights('/home/amplifier/home/NEW_DL/weights/EEGnet_CNN_Dense_Binary_Classifier_TD_1D_wts.h5')
# let's predict a TRAINING sammple:
decoded_train = model.predict(x_train)
decoded_test = model.predict(x_test)
print(decoded_train.shape)
print(decoded_test.shape)
# Out:
# (337, 2)
# (113, 2)

# %%
f, axs = plt.subplots(1,3,figsize=(15,5))
plt.subplot(131)
plt.plot(loss_history.batch_loss)
tic = np.linspace(0, len(loss_history.batch_loss), len(train_history.history['val_loss']))
plt.plot(tic, train_history.history['loss'])
plt.plot(tic, train_history.history['val_loss'])
plt.title('Loss dynamics')
plt.ylabel('loss')
plt.xlabel('batch')
plt.legend(['loss (by batch)', 'loss', 'val_loss'])

plt.subplot(132)
plt.plot(loss_history.lr,'bo')
plt.title('Learning rate dynamics over epochs')
plt.ylabel('lrate')
plt.xlabel('epoch')

asa = []
optimizer_name = model.optimizer.__class__.__name__
plt.subplot(133)
plt.plot(train_history.history['val_acc'])
plt.plot(train_history.history['acc'])
asa.append('val_acc ' + optimizer_name)
asa.append('acc ' + optimizer_name)
plt.title('Accuracy dynamics over epochs')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(asa)

plt.tight_layout()

# %%
# now test sample by sample
cor_test = []
L = x_test.shape
for sample_no in range(x_test.shape[0]):
    pred = model.predict(np.expand_dims(x_test[sample_no],0))
    if ((pred[0][0]<pred[0][1]) and (y_test[sample_no,0] < y_test[sample_no,1]) or
       ((pred[0][0]>pred[0][1]) and (y_test[sample_no,0] > y_test[sample_no,1]))):
        cor_test.append(1)
    else:
        cor_test.append(0)

cor_train = []
L = x_train.shape
for sample_no in range(x_train.shape[0]):
    pred = model.predict(np.expand_dims(x_train[sample_no],0))
    if ((pred[0][0]<pred[0][1]) and (y_train[sample_no,0] < y_train[sample_no,1]) or
       ((pred[0][0]>pred[0][1]) and (y_train[sample_no,0] > y_train[sample_no,1]))):
        cor_train.append(1)
    else:
        cor_train.append(0)

# Report accuracies
print('Accuracy on the test data:', np.mean(cor_test))
print('Accuracy on the training data:', np.mean(cor_train))
# Out:
# Accuracy on the test data: 0.8495575221238938
# Accuracy on the training data: 0.9821958456973294

# %%
from sklearn.metrics import roc_curve, auc

fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test.ravel(), decoded_test.ravel())
auc_keras = auc(fpr_keras, tpr_keras)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (NB: when classes are imbalanced)')
plt.legend(loc='best')
plt.show()

# %%
# https://eli.thegreenplace.net/2018/depthwise-separable-convolutions-for-machine-learning/
clean_wts = model.layers[1].get_weights()
alt_wts = clean_wts
print('Weights shape:', alt_wts[0].shape)
print('Pointwise filters shape:', alt_wts[1].shape)
print('Biases shape:', alt_wts[2].shape)
# Out:
# Weights shape: (26, 60, 1)
# Pointwise filters shape: (1, 60, 3)
# Biases shape: (3,)

# %%
np.einsum('abc,def->af', alt_wts[0], alt_wts[1]).shape
# Out:
# (26, 3)

# %%
aa = model.layers[1].get_weights()
f, axs = plt.subplots(10,6,figsize=(15,5))
for i in range(10):
    for j in range(6):
        axs[i,j].plot(aa[0][:,(i+1)*(j+1)-1,0])

# %%
tmp.shape
# Out:
# (26, 20)

# %%
tmp = np.einsum('abc,def->af', alt_wts[0], alt_wts[1])
f, axs = plt.subplots(1,20,figsize=(15,5))
for i in range(1):
    for j in range(20):
        axs[i,j].plot(tmp[:,i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-145-fdd708bb9f19> in <module>()
#       3 for i in range(1):
#       4     for j in range(20):
# ----> 5         axs[i,j].plot(tmp[:,i])
#
# IndexError: too many indices for array

# %%
aa[2].shape
# Out:
# (20,)

# %%
from keras.layers import Conv2D

def testnet(inpt):
    QQ = Conv2D(5,(2,2), activation='linear', padding='same')(inpt)
    return Model(inpt, QQ)

# input_img = Input(shape=(leng, chan))
inpt = Input(shape=(4,4,3))
testmod = testnet(inpt)
testmod.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 4, 4, 3)           0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 5)           65
# =================================================================
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
wt = testmod.layers[1].get_weights()

# %%
wt[0].shape
# Out:
# (2, 2, 3, 5)

# %%
f, axs = plt.subplots(3,5,figsize=(15,5))
for i in range(3):
    for j in range(5):
        axs[i,j].imshow(wt[0][:,:,i,j])

# %%
wt[0][:,:,1,1]
# Out:
# array([[-0.29568154,  0.15938213],
#        [-0.08544907,  0.23716089]], dtype=float32)

# %%
plt.imshow(aa[0][:,:,-1])

# %%
# df_ = pd.DataFrame(columns=['algorithm',
#                            'SHUFFLE',
#                            'BATCH_SIZE',
#                            'TEST_TRAIN',
#                            'DS_FREQ',
#                            'n_bins',
#                            'RESIZE',
#                            'width',
#                            'height',
#                            'SENSITIVITY',
#                            'dataset',
#                            'val_acc',
#                            'acc'])

# df_.loc[0] = ['1D',
#               SHUFFLE,
#               BATCH_SIZE,
#               TEST_TRAIN,
#               DS_FREQ,
#               n_bins,
#               RESIZE,
#               width,
#               height,
#               SENSITIVITY,
#               file,
#               np.mean(cor_test),
#               np.mean(cor_train)]
# # df.to_csv('/home/amplifier/home/NEW_DL/weights/blank_document.csv', index=False)
# df = pd.read_csv('/home/amplifier/home/NEW_DL/weights/performances.csv')
# df = df.append(df_, ignore_index=True)
# df.drop_duplicates(subset=None, keep='first', inplace=True)
# df.to_csv('/home/amplifier/home/NEW_DL/weights/performances.csv', index=False)
# df = pd.read_csv('/home/amplifier/home/NEW_DL/weights/performances.csv')
# display(df)

# %%
# log performance to file:
# import csv   
# fields=['1D', 'MY04', np.mean(cor_test), np.mean(cor_train)]
# with open(r'/home/amplifier/home/NEW_DL/weights/document.csv', 'a') as f:
#     writer = csv.writer(f)
#     writer.writerow(fields)

# %%
W = []
GT = []

for i in range(len(decoded_test)):
    if decoded_test[i][0]<decoded_test[i][1]:
        W.append('right')
    if decoded_test[i][0]>decoded_test[i][1]:
        W.append('left')

    if y_test[i][0]<y_test[i][1]:
        GT.append('right')
    if y_test[i][0]>y_test[i][1]:
        GT.append('left')
        
from sklearn.metrics import confusion_matrix
labels = ['left', 'right'] # 1 for right, 0 for left
cm = confusion_matrix(GT, W, labels)
fig = plt.figure()
ax = fig.add_subplot(111)

ax.matshow(cm)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
print(cm)
# Out:
# [[47 13]
#  [ 3 50]]

# %%
# Visualize a few kernels from the first convolutional layer:
# enc.layers[2].get_config()
# dir(enc.layers[2])
x = model.layers[1].get_weights()
print ('Layer number:', 2, 'Layer name:', model.layers[1].name)
sh = x[0].shape
print(sh) # kernel length x input channels x output channels

# I = sh[1]
# J = sh[2]
I = 10
J = 8
c = 0
fig, axs = plt.subplots(I,J)
fig.set_size_inches(18.5, 10.5)
axs = axs.ravel()
for i in range(I):
    for j in range(J):
        axs[c].plot(x[0][:,i,j])
        axs[c].get_xaxis().set_visible(False)
        axs[c].get_yaxis().set_visible(False)        
        axs[c].set_title(str(i)+str(j))
        c = c + 1
plt.suptitle('Convolution kernels in layer ' + model.layers[2].name, fontsize=26)
# Out:
# Layer number: 2 Layer name: separable_conv1d_11
# (26, 60, 1)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-676cd8918e11> in <module>()
#      17 for i in range(I):
#      18     for j in range(J):
# ---> 19         axs[c].plot(x[0][:,i,j])
#      20         axs[c].get_xaxis().set_visible(False)
#      21         axs[c].get_yaxis().set_visible(False)
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
get_1st_conv_layer_output = K.function([model.layers[0].input],
                                  [model.layers[3].output])
layer_output = get_1st_conv_layer_output([np.expand_dims(x_train[3],0)])[0]

im = layer_output[-1,:,:]
plt.imshow(im.T)
plt.suptitle(('Output of layer ' + model.layers[2].name), fontsize=26)
# Out:
# Text(0.5,0.98,'Output of layer elu_16')

# %%
import scipy.fftpack

x = model.layers[1].get_weights()

# I = x[0].shape[1]
# J = x[0].shape[2]
I = 10
J = 8
c = 0

fs = 250
T = 1/fs * x[0].shape[0]
f = 50
t = np.arange(0,T, 1/fs)

fig, axs = plt.subplots(I,J)
fig.set_size_inches(18.5, 10.5)
axs = axs.ravel()
for i in range(I):
    for j in range(J):
        y = x[0][:,i,j].reshape(KERNEL_SIZE[0],1)
        yf = scipy.fftpack.fft(y, axis=0)

        YF = np.abs(yf)
        xf = np.linspace(0,fs/2, YF.shape[0]/2)
        YF_trunc = YF[0:int(len(YF)/2),-1]
        axs[c].plot(xf, YF_trunc)
        axs[c].get_xaxis().set_visible(True)
        axs[c].get_yaxis().set_visible(False)        
        axs[c].set_title(str(i)+str(j))
        c = c + 1

plt.tight_layout()
plt.suptitle('FFT of kernels in layer ' + model.layers[2].name, fontsize=26)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:25: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# Text(0.5,0.98,'FFT of kernels in layer elu_16')

# %%
y = x[0][:,20,9].reshape(KERNEL_SIZE[0],1)
yf = scipy.fftpack.fft(y, axis=0)

YF = np.abs(yf)
xf = np.linspace(0,fs/2, YF.shape[0]/2)
YF_trunc = YF[0:int(len(YF)/2),-1]
plt.plot(xf, YF_trunc)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """

# %%
# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot

# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
# import pandas as pd
# df = pd.read_csv('/home/amplifier/home/NEW_DL/weights/document.csv')

# %%
# df.head()

# %%
# import csv   
# fields=['algorithm', 'dataset', 'val_acc', 'acc']
# with open(r'/home/amplifier/home/NEW_DL/weights/document.csv', 'w') as f:
#     writer = csv.writer(f)
#     writer.writerow(fields)

# %%
# df[df.algorithm=='1D'].acc.min()
