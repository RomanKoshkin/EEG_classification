# %%
# make sure you don't hog all the video memory
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
from keras import backend as K
K.set_session(sess)
###################################
from keras.layers import Input, Conv2D, Lambda, merge, Dense, Flatten,MaxPooling2D
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
import numpy.random as rng
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
# %matplotlib inline
def W_init(shape,name=None):
    """Initialize weights as in paper"""
    values = rng.normal(loc=0,scale=1e-2,size=shape)
    return K.variable(values,name=name)
#//TODO: figure out how to initialize layer biases in keras.
def b_init(shape,name=None):
    """Initialize bias as in paper"""
    values=rng.normal(loc=0.5,scale=1e-2,size=shape)
    return K.variable(values,name=name)

input_shape = (105, 105, 1)
left_input = Input(input_shape)
right_input = Input(input_shape)
#build convnet to use in each siamese 'leg'
convnet = Sequential()
convnet.add(Conv2D(32,(10,10),activation='relu',input_shape=input_shape,
                   kernel_initializer=W_init,kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(64,(7,7),activation='relu',
                   kernel_regularizer=l2(2e-4),kernel_initializer=W_init,bias_initializer=b_init))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(64,(4,4),activation='relu',kernel_initializer=W_init,kernel_regularizer=l2(2e-4),bias_initializer=b_init))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128,(4,4),activation='relu',kernel_initializer=W_init,kernel_regularizer=l2(2e-4),bias_initializer=b_init))
convnet.add(Flatten())
convnet.add(Dense(2048,activation="sigmoid",kernel_regularizer=l2(1e-3),kernel_initializer=W_init,bias_initializer=b_init))

#call the convnet Sequential model on each of the input tensors so params will be shared
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)
#layer to merge two encoded inputs with the l1 distance between them
L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
#call this layer on list of two input tensors.
L1_distance = L1_layer([encoded_l, encoded_r])
prediction = Dense(1,activation='sigmoid',bias_initializer=b_init)(L1_distance)
siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

optimizer = Adam(0.00006)
#//TODO: get layerwise learning rates and momentum annealing scheme described in paperworking
siamese_net.compile(loss="binary_crossentropy",optimizer=optimizer)

siamese_net.count_params()
# Out:
# 9741729

# %%
siamese_net.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, 2048)         9739680     input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 2048)         0           sequential_4[1][0]
#                                                                  sequential_4[2][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2049        lambda_2[0][0]
# ==================================================================================================
# Total params: 9,741,729
# Trainable params: 9,741,729
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
PATH = "/home/amplifier/home/DATASETS" #CHANGE THIS - path where the pickled data is stored

with open(os.path.join(PATH, "train.pickle"), "rb") as f:
    (X,c) = pickle.load(f)

with open(os.path.join(PATH, "val.pickle"), "rb") as f:
    (Xval,cval) = pickle.load(f)
    
print("training alphabets")
print(c.keys())
print("validation alphabets:")
print(cval.keys())
# Out:
# training alphabets
# dict_keys(['Malay_(Jawi_-_Arabic)', 'Japanese_(hiragana)', 'Sanskrit', 'Japanese_(katakana)', 'Gujarati', 'Greek', 'Syriac_(Estrangelo)', 'Mkhedruli_(Georgian)', 'Burmese_(Myanmar)', 'Braille', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Arcadian', 'Korean', 'Tagalog', 'Cyrillic', 'N_Ko', 'Latin', 'Tifinagh', 'Futurama', 'Early_Aramaic', 'Anglo-Saxon_Futhorc', 'Asomtavruli_(Georgian)', 'Grantha', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Balinese', 'Armenian', 'Alphabet_of_the_Magi', 'Hebrew', 'Bengali'])
# validation alphabets:
# dict_keys(['Malayalam', 'Kannada', 'Sylheti', 'Aurek-Besh', 'Atemayar_Qelisayer', 'Syriac_(Serto)', 'Glagolitic', 'Mongolian', 'Tengwar', 'Keble', 'Old_Church_Slavonic_(Cyrillic)', 'Atlantean', 'Tibetan', 'Oriya', 'Manipuri', 'ULOG', 'Ge_ez', 'Gurmukhi', 'Angelic', 'Avesta'])

# %%
class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self, path, data_subsets = ["train", "val"]):
        self.data = {}
        self.categories = {}
        self.info = {}
        
        for name in data_subsets:
            file_path = os.path.join(path, name + ".pickle")
            print("loading data from {}".format(file_path))
            with open(file_path,"rb") as f:
                (X,c) = pickle.load(f)
                self.data[name] = X
                self.categories[name] = c

    def get_batch(self,batch_size,s="train"):
        """Create batch of n pairs, half same class, half different class"""
        X=self.data[s]
        n_classes, n_examples, w, h = X.shape

        #randomly sample several classes to use in the batch
        categories = rng.choice(n_classes,size=(batch_size,),replace=False)
        cat2 = np.zeros_like(categories)
        #initialize 2 empty arrays for the input image batch
        pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets=np.zeros((batch_size,))
        targets[batch_size//2:] = 1
        for i in range(batch_size):
            category = categories[i]
            idx_1 = rng.randint(0, n_examples) # generate one random integer in [0:n_examples] to pick random example of the class
            pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1) # put in left column of arrays
            idx_2 = rng.randint(0, n_examples) # generate another random integer in [0:n_examples] to pick another example of same class
            #pick images of same class for 1st half, different for 2nd
            if i >= batch_size // 2:
                category_2 = category  
            else: 
                #add a random number to the category modulo n classes to ensure 2nd image has
                # ..different category
                category_2 = (category + rng.randint(1,n_classes)) % n_classes
                cat2[i] = category_2
            pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
        return pairs, targets, categories, cat2
    
    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size,s)
            yield (pairs, targets)    

    def make_oneshot_task(self,N,s="val",language=None):
        """Create pairs of test image, support set for testing N way one-shot learning. """
        X=self.data[s]
        n_classes, n_examples, w, h = X.shape
        indices = rng.randint(0,n_examples,size=(N,))
        if language is not None:
            low, high = self.categories[s][language]
            if N > high - low:
                raise ValueError("This language ({}) has less than {} letters".format(language, N))
            categories = rng.choice(range(low,high),size=(N,),replace=False)
            
        else:#if no language specified just pick a bunch of random letters
            categories = rng.choice(range(n_classes),size=(N,),replace=False)            
        true_category = categories[0]
        ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
        test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
        support_set = X[categories,indices,:,:]
        support_set[0,:,:] = X[true_category,ex2]
        support_set = support_set.reshape(N, w, h,1)
        targets = np.zeros((N,))
        targets[0] = 1
        targets, test_image, support_set = shuffle(targets, test_image, support_set)
        pairs = [test_image,support_set]

        return pairs, targets
    
    def test_oneshot(self,model,N,k,s="val",verbose=0):
        """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
        n_correct = 0
        if verbose:
            print("Evaluating model on {} random {} way one-shot learning tasks ...".format(k,N))
        for i in range(k):
            inputs, targets = self.make_oneshot_task(N,s)
            probs = model.predict(inputs)
            if np.argmax(probs) == np.argmax(targets):
                n_correct+=1
        percent_correct = (100.0*n_correct / k)
        if verbose:
            print("Got an average of {}% {} way one-shot learning accuracy".format(percent_correct,N))
        return percent_correct
    
    def train(self, model, epochs, verbosity):
        model.fit_generator(self.generate(batch_size),)
    
    
#Instantiate the class
loader = Siamese_Loader(PATH)
# Out:
# loading data from /home/amplifier/home/DATASETS/train.pickle
# loading data from /home/amplifier/home/DATASETS/val.pickle

# %%
inputs, targets = loader.make_oneshot_task(3,s='val')
probs = siamese_net.predict(inputs)
print(probs, '\n', targets)
if np.argmax(probs) == np.argmax(targets):
    print('correct!')
# Out:
# [[ 0.9363662 ]
#  [ 0.52201384]
#  [ 0.00929203]]
#  [ 1.  0.  0.]
# correct!

# %%
pairs[0].shape
# Out:
# (9, 105, 105, 1)

# %%
pairs, targets, categories, cat2 = loader.get_batch(9,'train')
print(categories)
print(cat2)
print(targets)
# Out:
# [784 962 563 700 543 459 470 393 214]
# [872  55 953 279 543 459 470 393 214]
# [ 0.  0.  0.  0.  1.  1.  1.  1.  1.]

# %%
pairs, targets = loader.get_batch(9,'train')

fig, axs = plt.subplots(3,3)
axs = axs.ravel()
for i in range(9):
    axs[i].imshow(pairs[0][i,:,:,-1])
    plt.tight_layout()
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False) 
    axs[i].set_title(targets[i])

fig, axs = plt.subplots(3,3)
axs = axs.ravel()
for i in range(9):
    axs[i].imshow(pairs[1][i,:,:,-1])
    plt.tight_layout()
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False) 
    axs[i].set_title(targets[i])
# Out:
# [821 692 516 645 940  24 243 155  35] line23

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc,h,w,_ = X.shape
    X = X.reshape(nc,h,w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img


def plot_oneshot_task(pairs):
    """Takes a one-shot task given to a siamese net and  """
    fig,(ax1,ax2) = plt.subplots(2)
    ax1.matshow(pairs[0][0].reshape(105,105),cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()
#example of a one-shot learning task
pairs, targets = loader.make_oneshot_task(20,"train","Japanese_(katakana)")
plot_oneshot_task(pairs)

# %%
# print('data', loader.data['train'].shape)
print('data[`train`]', loader.data['train'].shape)
print('data[`val`]', loader.data['val'].shape)
loader.categories['train']

X = loader.data['train'][476:508,:,:,:]

fig, axs = plt.subplots(4,4)
axs = axs.ravel()
for i in range(16):
    axs[i].imshow(X[4,i,:,:])
    plt.tight_layout()
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False) 
    axs[i].set_title(targets[i])
# Out:
# data[`train`] (964, 20, 105, 105)
# data[`val`] (659, 20, 105, 105)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-df45df61ddcc> in <module>()
# ----> 1 inputs[2].shape
#
# IndexError: list index out of range

# %%
#Training loop
print("!")
evaluate_every = 1 # interval for evaluating on one-shot tasks
loss_every=5 # interval for printing loss (iterations)
batch_size = 32
n_iter = 100
N_way = 20 # how many classes for testing one-shot tasks>
n_val = 50 #how mahy one-shot tasks to validate on?
best = -1
weights_path = os.path.join(PATH, "weights")
print("training")
for i in range(1, n_iter):
    (inputs,targets)=loader.get_batch(batch_size)
    loss=siamese_net.train_on_batch(inputs,targets)
    print(loss)
    if i % evaluate_every == 0:
        print("evaluating")
        val_acc = loader.test_oneshot(siamese_net,N_way,n_val,verbose=True)
        if val_acc >= best:
            print("saving")
            siamese_net.save(weights_path)
            best=val_acc

    if i % loss_every == 0:
        print("iteration {}, training loss: {:.2f},".format(i,loss))
# Out:
# !
# training
# 0.897654
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# saving
# 0.564543
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# saving
# 0.725332
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.795161
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# saving
# 0.636584
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# iteration 5, training loss: 0.64,
# 0.653552
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.582627
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.7717
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# saving
# 0.672184
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# saving
# 0.557825
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 62.0% 20 way one-shot learning accuracy
# saving
# iteration 10, training loss: 0.56,
# 0.490517
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 36.0% 20 way one-shot learning accuracy
# 0.60005
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.632455
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.629072
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# 0.592699
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# iteration 15, training loss: 0.59,
# 0.646706
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.570246
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# 0.572887
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 58.0% 20 way one-shot learning accuracy
# 0.609289
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.838712
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# iteration 20, training loss: 0.84,
# 0.605487
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.668655
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.608896
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 38.0% 20 way one-shot learning accuracy
# 0.661875
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# 0.676218
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# iteration 25, training loss: 0.68,
# 0.70482
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.546616
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.541839
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.562506
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 0.6497
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# iteration 30, training loss: 0.65,
# 0.760104
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.710802
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 60.0% 20 way one-shot learning accuracy
# 0.6557
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# 0.693691
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.756609
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# iteration 35, training loss: 0.76,
# 0.565908
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.77866
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 0.709549
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.794839
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# 0.822976
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# iteration 40, training loss: 0.82,
# 0.58757
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.809466
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.527004
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.555552
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 38.0% 20 way one-shot learning accuracy
# 0.721054
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# iteration 45, training loss: 0.72,
# 0.692223
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.705789
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 0.705304
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# 0.881959
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.652776
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# iteration 50, training loss: 0.65,
# 0.622288
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.611617
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.585532
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# 0.539844
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.676827
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# iteration 55, training loss: 0.68,
# 0.582502
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# 0.65092
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 38.0% 20 way one-shot learning accuracy
# 0.538534
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.5997
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.646192
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# iteration 60, training loss: 0.65,
# 0.686566
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 60.0% 20 way one-shot learning accuracy
# 0.532077
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.706006
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.801431
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 0.541771
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# iteration 65, training loss: 0.54,
# 0.485749
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# 0.613169
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 38.0% 20 way one-shot learning accuracy
# 0.677565
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.639192
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.67636
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# iteration 70, training loss: 0.68,
# 0.605036
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.753292
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.511572
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.59263
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 36.0% 20 way one-shot learning accuracy
# 0.68815
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 38.0% 20 way one-shot learning accuracy
# iteration 75, training loss: 0.69,
# 0.682763
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.470865
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.632792
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 0.581641
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# 0.561678
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# iteration 80, training loss: 0.56,
# 0.68889
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.615854
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.803419
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# 0.562183
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 0.5347
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# iteration 85, training loss: 0.53,
# 0.497931
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.758328
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.540258
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# 0.726632
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 0.465614
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 62.0% 20 way one-shot learning accuracy
# saving
# iteration 90, training loss: 0.47,
# 0.933158
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# 0.518674
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy
# 0.789279
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 0.649236
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.550678
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 44.0% 20 way one-shot learning accuracy
# iteration 95, training loss: 0.55,
# 0.587316
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 42.0% 20 way one-shot learning accuracy
# 0.704412
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 0.670406
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 40.0% 20 way one-shot learning accuracy
# 0.603909
# evaluating
# Evaluating model on 50 random 20 way one-shot learning tasks ...
# Got an average of 46.0% 20 way one-shot learning accuracy

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0


def test_nn_accuracy(N_ways,n_trials,loader):
    """Returns accuracy of one shot """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0
    
    for i in range(n_trials):
        pairs,targets = loader.make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials


ways = np.arange(1, 10, 2)
resume =  False
val_accs, train_accs,nn_accs = [], [], []
trials = 450
for N in ways:
    val_accs.append(loader.test_oneshot(siamese_net, N,trials, "val", verbose=True))
    train_accs.append(loader.test_oneshot(siamese_net, N,trials, "train", verbose=True))
    nn_accs.append(test_nn_accuracy(N,trials, loader))
    
#plot the accuracy vs num categories for each
plt.plot(ways, val_accs, "m")
plt.plot(ways, train_accs, "y")
plt.plot(ways, nn_accs, "c")

plt.plot(ways,100.0/ways,"r")
plt.show()
# Out:
# Evaluating model on 450 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating model on 450 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 1 way one-shot learning tasks ...
# Evaluating model on 450 random 3 way one-shot learning tasks ...
# Got an average of 85.77777777777777% 3 way one-shot learning accuracy
# Evaluating model on 450 random 3 way one-shot learning tasks ...
# Got an average of 89.33333333333333% 3 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 3 way one-shot learning tasks ...
# Evaluating model on 450 random 5 way one-shot learning tasks ...
# Got an average of 74.66666666666667% 5 way one-shot learning accuracy
# Evaluating model on 450 random 5 way one-shot learning tasks ...
# Got an average of 82.22222222222223% 5 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 5 way one-shot learning tasks ...
# Evaluating model on 450 random 7 way one-shot learning tasks ...
# Got an average of 68.44444444444444% 7 way one-shot learning accuracy
# Evaluating model on 450 random 7 way one-shot learning tasks ...
# Got an average of 74.22222222222223% 7 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 7 way one-shot learning tasks ...
# Evaluating model on 450 random 9 way one-shot learning tasks ...
# Got an average of 62.22222222222222% 9 way one-shot learning accuracy
# Evaluating model on 450 random 9 way one-shot learning tasks ...
# Got an average of 71.55555555555556% 9 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 9 way one-shot learning tasks ...

# %%
fig,ax = plt.subplots(1)
ax.plot(ways,val_accs,"m",label="Siamese(val set)")
ax.plot(ways,train_accs,"y",label="Siamese(train set)")
plt.plot(ways,nn_accs,label="Nearest neighbour")

ax.plot(ways,100.0/ways,"g",label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = loader.make_oneshot_task(20,"val")
plt.show()

print(inputs[0].shape)
plot_oneshot_task(inputs)
p=siamese_net.predict(inputs)
print(p)
# Out:
# (20, 105, 105, 1)
# [[ 0.00348877]
#  [ 0.0157997 ]
#  [ 0.28967839]
#  [ 0.57806921]
#  [ 0.04346752]
#  [ 0.35444683]
#  [ 0.59059161]
#  [ 0.01919593]
#  [ 0.01354892]
#  [ 0.06931842]
#  [ 0.43609771]
#  [ 0.62392259]
#  [ 0.74978048]
#  [ 0.61716866]
#  [ 0.81980419]
#  [ 0.04432191]
#  [ 0.13751546]
#  [ 0.14057466]
#  [ 0.01723291]
#  [ 0.24789886]]

# %%
a=test_nn_accuracy(3,500,loader)
print(a)
# Out:
# Evaluating nearest neighbour on 500 unique 3 way one-shot learning tasks ...
# 54.6

# %%
pairs, targets = loader.get_batch(32,'train')

fig, axs = plt.subplots(4,8)
axs = axs.ravel()
for i in range(32):
    axs[i].imshow(pairs[0][i,:,:,-1])
    plt.tight_layout()
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False) 


fig, axs = plt.subplots(4,8)
axs = axs.ravel()
for i in range(32):
    axs[i].imshow(pairs[1][i,:,:,-1])
    plt.tight_layout()
    axs[i].get_xaxis().set_visible(False)
    axs[i].get_yaxis().set_visible(False)
